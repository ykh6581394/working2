# %%
import pandas as pd
import numpy as np
from urllib.request import urlopen
from bs4 import BeautifulSoup

result = pd.DataFrame({'음식':[1],'재료':[1]})
page_number=1
while True:
    
    
    #print(page_number)
    html = urlopen("https://www.menupan.com/Cook/recipere.asp?nation=20&page="+str(page_number))
    bsObject = BeautifulSoup(html, "lxml", from_encoding='utf-8')
    
    #메뉴 수집
    menus = bsObject.findAll('span', {"class":"link"})

    menu_list = []
    for menu in menus:
        menu_tmp =menu.get_text()
        menu_list.append(menu_tmp)
    fd_nm = pd.DataFrame({'음식':menu_list})
    
  
    if len(fd_nm)==0:
        break

    # 재료 수집
    ingredients= bsObject.findAll('td', {"valign":"top"})
    ingred_list = []

    for ingredient in ingredients[5:]:
        tmp = ingredient.findAll('td')
        for i in tmp:
            tmp_text = i.get_text()
            if tmp_text ==None:
                continue
            else:
                if '주재료:' in tmp_text:
                    
                    ingred_list.append(tmp_text[4:].replace(',','').split())
                    #print(ingred_list)
          
                       
    ingred_nm = pd.DataFrame({'재료': ingred_list})
    #print(ingred_nm)
    
    tmp_result = pd.concat([fd_nm, ingred_nm],axis=1)
    
    #print(tmp_result)
    
    result = pd.concat([result, tmp_result])
    page_number +=1

result = result[1:]
result = result.set_index(np.array(range(len(result))))
# Out:
# [['감자', '양파', '대파', '버터', '육수', '계란노른자', '생크림']]
# [['감자', '양파', '대파', '버터', '육수', '계란노른자', '생크림'], ['고구마', '우유']]
# [['감자', '양파', '대파', '버터', '육수', '계란노른자', '생크림'], ['고구마', '우유'], ['단호박', '양파', '버터', '밀가루', '물', '우유', '생크림']]
# [['감자', '양파', '대파', '버터', '육수', '계란노른자', '생크림'], ['고구마', '우유'], ['단호박', '양파', '버터', '밀가루', '물', '우유', '생크림'], ['닭', '당근', '양파', '밀가루', '버터', '우유', '닭육수']]
# [['감자', '양파', '대파', '버터', '육수', '계란노른자', '생크림'], ['고구마', '우유'], ['단호박', '양파', '버터', '밀가루', '물', '우유', '생크림'], ['닭', '당근', '양파', '밀가루', '버터', '우유', '닭육수'], ['버터', '양파', '당근', '크림치즈', '우유', '다진파슬리']]
# [['감자', '양파', '대파', '버터', '육수', '계란노른자', '생크림'], ['고구마', '우유'], ['단호박', '양파', '버터', '밀가루', '물', '우유', '생크림'], ['닭', '당근', '양파', '밀가루', '버터', '우유', '닭육수'], ['버터', '양파', '당근', '크림치즈', '우유', '다진파슬리'], ['쇠고기', '양파', '당근', '감자', '샐러리', '버터']]
# [['감자', '양파', '대파', '버터', '육수', '계란노른자', '생크림'], ['고구마', '우유'], ['단호박', '양파', '버터', '밀가루', '물', '우유', '생크림'], ['닭', '당근', '양파', '밀가루', '버터', '우유', '닭육수'], ['버터', '양파', '당근', '크림치즈', '우유', '다진파슬리'], ['쇠고기', '양파', '당근', '감자', '샐러리', '버터'], ['콩', '깨', '잣', '호두', '식빵']]
# [['감자', '양파', '대파', '버터', '육수', '계란노른자', '생크림'], ['고구마', '우유'], ['단호박', '양파', '버터', '밀가루', '물', '우유', '생크림'], ['닭', '당근', '양파', '밀가루', '버터', '우유', '닭육수'], ['버터', '양파', '당근', '크림치즈', '우유', '다진파슬리'], ['쇠고기', '양파', '당근', '감자', '샐러리', '버터'], ['콩', '깨', '잣', '호두', '식빵'], ['버섯', '버터']]
# [['감자', '양파', '대파', '버터', '육수', '계란노른자', '생크림'], ['고구마', '우유'], ['단호박', '양파', '버터', '밀가루', '물', '우유', '생크림'], ['닭', '당근', '양파', '밀가루', '버터', '우유', '닭육수'], ['버터', '양파', '당근', '크림치즈', '우유', '다진파슬리'], ['쇠고기', '양파', '당근', '감자', '샐러리', '버터'], ['콩', '깨', '잣', '호두', '식빵'], ['버섯', '버터'], ['버터', '양파', '감자', '양송이']]
# [['감자', '양파', '대파', '버터', '육수', '계란노른자', '생크림'], ['고구마', '우유'], ['단호박', '양파', '버터', '밀가루', '물', '우유', '생크림'], ['닭', '당근', '양파', '밀가루', '버터', '우유', '닭육수'], ['버터', '양파', '당근', '크림치즈', '우유', '다진파슬리'], ['쇠고기', '양파', '당근', '감자', '샐러리', '버터'], ['콩', '깨', '잣', '호두', '식빵'], ['버섯', '버터'], ['버터', '양파', '감자', '양송이'], ['베비이콘', '당근', '완두콩', '양파', '토마토']]
# [['감자', '양파', '대파', '버터', '육수', '계란노른자', '생크림'], ['고구마', '우유'], ['단호박', '양파', '버터', '밀가루', '물', '우유', '생크림'], ['닭', '당근', '양파', '밀가루', '버터', '우유', '닭육수'], ['버터', '양파', '당근', '크림치즈', '우유', '다진파슬리'], ['쇠고기', '양파', '당근', '감자', '샐러리', '버터'], ['콩', '깨', '잣', '호두', '식빵'], ['버섯', '버터'], ['버터', '양파', '감자', '양송이'], ['베비이콘', '당근', '완두콩', '양파', '토마토'], ['브로콜리', '양파', '대파', '밥', '생크림', '시금치', '닭육수', '버터']]
# [['감자', '양파', '대파', '버터', '육수', '계란노른자', '생크림'], ['고구마', '우유'], ['단호박', '양파', '버터', '밀가루', '물', '우유', '생크림'], ['닭', '당근', '양파', '밀가루', '버터', '우유', '닭육수'], ['버터', '양파', '당근', '크림치즈', '우유', '다진파슬리'], ['쇠고기', '양파', '당근', '감자', '샐러리', '버터'], ['콩', '깨', '잣', '호두', '식빵'], ['버섯', '버터'], ['버터', '양파', '감자', '양송이'], ['베비이콘', '당근', '완두콩', '양파', '토마토'], ['브로콜리', '양파', '대파', '밥', '생크림', '시금치', '닭육수', '버터'], ['브로콜리', '버터', '밀가루', '우유', '생크림']]
# [['감자', '양파', '대파', '버터', '육수', '계란노른자', '생크림'], ['고구마', '우유'], ['단호박', '양파', '버터', '밀가루', '물', '우유', '생크림'], ['닭', '당근', '양파', '밀가루', '버터', '우유', '닭육수'], ['버터', '양파', '당근', '크림치즈', '우유', '다진파슬리'], ['쇠고기', '양파', '당근', '감자', '샐러리', '버터'], ['콩', '깨', '잣', '호두', '식빵'], ['버섯', '버터'], ['버터', '양파', '감자', '양송이'], ['베비이콘', '당근', '완두콩', '양파', '토마토'], ['브로콜리', '양파', '대파', '밥', '생크림', '시금치', '닭육수', '버터'], ['브로콜리', '버터', '밀가루', '우유', '생크림'], ['계란', '밥', '양파', '햄', '청피망', '당근']]
# [['감자', '양파', '대파', '버터', '육수', '계란노른자', '생크림'], ['고구마', '우유'], ['단호박', '양파', '버터', '밀가루', '물', '우유', '생크림'], ['닭', '당근', '양파', '밀가루', '버터', '우유', '닭육수'], ['버터', '양파', '당근', '크림치즈', '우유', '다진파슬리'], ['쇠고기', '양파', '당근', '감자', '샐러리', '버터'], ['콩', '깨', '잣', '호두', '식빵'], ['버섯', '버터'], ['버터', '양파', '감자', '양송이'], ['베비이콘', '당근', '완두콩', '양파', '토마토'], ['브로콜리', '양파', '대파', '밥', '생크림', '시금치', '닭육수', '버터'], ['브로콜리', '버터', '밀가루', '우유', '생크림'], ['계란', '밥', '양파', '햄', '청피망', '당근'], ['양송이버섯', '육수', '생크림', '버터', '밀가루', '우유', '물']]
# [['감자', '양파', '대파', '버터', '육수', '계란노른자', '생크림'], ['고구마', '우유'], ['단호박', '양파', '버터', '밀가루', '물', '우유', '생크림'], ['닭', '당근', '양파', '밀가루', '버터', '우유', '닭육수'], ['버터', '양파', '당근', '크림치즈', '우유', '다진파슬리'], ['쇠고기', '양파', '당근', '감자', '샐러리', '버터'], ['콩', '깨', '잣', '호두', '식빵'], ['버섯', '버터'], ['버터', '양파', '감자', '양송이'], ['베비이콘', '당근', '완두콩', '양파', '토마토'], ['브로콜리', '양파', '대파', '밥', '생크림', '시금치', '닭육수', '버터'], ['브로콜리', '버터', '밀가루', '우유', '생크림'], ['계란', '밥', '양파', '햄', '청피망', '당근'], ['양송이버섯', '육수', '생크림', '버터', '밀가루', '우유', '물'], ['버터', '양파', '감자', '양송이버섯', '생크림']]
#                                       재료
# 0       [감자, 양파, 대파, 버터, 육수, 계란노른자, 생크림]
# 1                              [고구마, 우유]
# 2         [단호박, 양파, 버터, 밀가루, 물, 우유, 생크림]
# 3          [닭, 당근, 양파, 밀가루, 버터, 우유, 닭육수]
# 4          [버터, 양파, 당근, 크림치즈, 우유, 다진파슬리]
# 5             [쇠고기, 양파, 당근, 감자, 샐러리, 버터]
# 6                      [콩, 깨, 잣, 호두, 식빵]
# 7                               [버섯, 버터]
# 8                      [버터, 양파, 감자, 양송이]
# 9               [베비이콘, 당근, 완두콩, 양파, 토마토]
# 10  [브로콜리, 양파, 대파, 밥, 생크림, 시금치, 닭육수, 버터]
# 11              [브로콜리, 버터, 밀가루, 우유, 생크림]
# 12               [계란, 밥, 양파, 햄, 청피망, 당근]
# 13      [양송이버섯, 육수, 생크림, 버터, 밀가루, 우유, 물]
# 14              [버터, 양파, 감자, 양송이버섯, 생크림]
# [['양파', '바게트빵', '마늘', '올리브오일', '치킨육수', '물']]
# [['양파', '바게트빵', '마늘', '올리브오일', '치킨육수', '물'], ['계란', '양파', '당근', '밥', '청피망', '홍피망', '오이', '전분']]
# [['양파', '바게트빵', '마늘', '올리브오일', '치킨육수', '물'], ['계란', '양파', '당근', '밥', '청피망', '홍피망', '오이', '전분'], ['옥수수', '양파', '우유']]
# [['양파', '바게트빵', '마늘', '올리브오일', '치킨육수', '물'], ['계란', '양파', '당근', '밥', '청피망', '홍피망', '오이', '전분'], ['옥수수', '양파', '우유'], ['완두콩', '감자', '양파', '우유']]
# [['양파', '바게트빵', '마늘', '올리브오일', '치킨육수', '물'], ['계란', '양파', '당근', '밥', '청피망', '홍피망', '오이', '전분'], ['옥수수', '양파', '우유'], ['완두콩', '감자', '양파', '우유'], ['완두콩', '물', '감자', '버터', '밀가루', '생크림']]
# [['양파', '바게트빵', '마늘', '올리브오일', '치킨육수', '물'], ['계란', '양파', '당근', '밥', '청피망', '홍피망', '오이', '전분'], ['옥수수', '양파', '우유'], ['완두콩', '감자', '양파', '우유'], ['완두콩', '물', '감자', '버터', '밀가루', '생크림'], ['밥', '쇠고기', '양파', '당근', '감자', '사과', '오렌지', '옥수수', '버터', '카레', '물', '건포도']]
# [['양파', '바게트빵', '마늘', '올리브오일', '치킨육수', '물'], ['계란', '양파', '당근', '밥', '청피망', '홍피망', '오이', '전분'], ['옥수수', '양파', '우유'], ['완두콩', '감자', '양파', '우유'], ['완두콩', '물', '감자', '버터', '밀가루', '생크림'], ['밥', '쇠고기', '양파', '당근', '감자', '사과', '오렌지', '옥수수', '버터', '카레', '물', '건포도'], ['토마토', '홍피망', '오이', '양파', '올리브오일', '물', '토마토주스', '크루통']]
# [['양파', '바게트빵', '마늘', '올리브오일', '치킨육수', '물'], ['계란', '양파', '당근', '밥', '청피망', '홍피망', '오이', '전분'], ['옥수수', '양파', '우유'], ['완두콩', '감자', '양파', '우유'], ['완두콩', '물', '감자', '버터', '밀가루', '생크림'], ['밥', '쇠고기', '양파', '당근', '감자', '사과', '오렌지', '옥수수', '버터', '카레', '물', '건포도'], ['토마토', '홍피망', '오이', '양파', '올리브오일', '물', '토마토주스', '크루통'], ['감자', '당근', '양파', '샐러리', '양송이버섯', '홀토마토', '물', '버터']]
# [['양파', '바게트빵', '마늘', '올리브오일', '치킨육수', '물'], ['계란', '양파', '당근', '밥', '청피망', '홍피망', '오이', '전분'], ['옥수수', '양파', '우유'], ['완두콩', '감자', '양파', '우유'], ['완두콩', '물', '감자', '버터', '밀가루', '생크림'], ['밥', '쇠고기', '양파', '당근', '감자', '사과', '오렌지', '옥수수', '버터', '카레', '물', '건포도'], ['토마토', '홍피망', '오이', '양파', '올리브오일', '물', '토마토주스', '크루통'], ['감자', '당근', '양파', '샐러리', '양송이버섯', '홀토마토', '물', '버터'], ['쇠고기스톡', '버터', '당근', '양파', '샐러리', '피망', '무']]
# [['양파', '바게트빵', '마늘', '올리브오일', '치킨육수', '물'], ['계란', '양파', '당근', '밥', '청피망', '홍피망', '오이', '전분'], ['옥수수', '양파', '우유'], ['완두콩', '감자', '양파', '우유'], ['완두콩', '물', '감자', '버터', '밀가루', '생크림'], ['밥', '쇠고기', '양파', '당근', '감자', '사과', '오렌지', '옥수수', '버터', '카레', '물', '건포도'], ['토마토', '홍피망', '오이', '양파', '올리브오일', '물', '토마토주스', '크루통'], ['감자', '당근', '양파', '샐러리', '양송이버섯', '홀토마토', '물', '버터'], ['쇠고기스톡', '버터', '당근', '양파', '샐러리', '피망', '무'], ['밥', '닭고기', '감자', '양파', '피망', '치즈', '밀가루', '계란', '빵가루', '튀김기름']]
# [['양파', '바게트빵', '마늘', '올리브오일', '치킨육수', '물'], ['계란', '양파', '당근', '밥', '청피망', '홍피망', '오이', '전분'], ['옥수수', '양파', '우유'], ['완두콩', '감자', '양파', '우유'], ['완두콩', '물', '감자', '버터', '밀가루', '생크림'], ['밥', '쇠고기', '양파', '당근', '감자', '사과', '오렌지', '옥수수', '버터', '카레', '물', '건포도'], ['토마토', '홍피망', '오이', '양파', '올리브오일', '물', '토마토주스', '크루통'], ['감자', '당근', '양파', '샐러리', '양송이버섯', '홀토마토', '물', '버터'], ['쇠고기스톡', '버터', '당근', '양파', '샐러리', '피망', '무'], ['밥', '닭고기', '감자', '양파', '피망', '치즈', '밀가루', '계란', '빵가루', '튀김기름'], ['닭', '카레', '밥', '식용유', '양송이버섯', '피망', '파프리카', '방울토마토', '꼬치']]
# [['양파', '바게트빵', '마늘', '올리브오일', '치킨육수', '물'], ['계란', '양파', '당근', '밥', '청피망', '홍피망', '오이', '전분'], ['옥수수', '양파', '우유'], ['완두콩', '감자', '양파', '우유'], ['완두콩', '물', '감자', '버터', '밀가루', '생크림'], ['밥', '쇠고기', '양파', '당근', '감자', '사과', '오렌지', '옥수수', '버터', '카레', '물', '건포도'], ['토마토', '홍피망', '오이', '양파', '올리브오일', '물', '토마토주스', '크루통'], ['감자', '당근', '양파', '샐러리', '양송이버섯', '홀토마토', '물', '버터'], ['쇠고기스톡', '버터', '당근', '양파', '샐러리', '피망', '무'], ['밥', '닭고기', '감자', '양파', '피망', '치즈', '밀가루', '계란', '빵가루', '튀김기름'], ['닭', '카레', '밥', '식용유', '양송이버섯', '피망', '파프리카', '방울토마토', '꼬치'], ['밥', '쇠고기', '양파', '마늘', '토마토', '칠리', '프랑크소시지', '대파', '버터', '밀가루', '물']]
# [['양파', '바게트빵', '마늘', '올리브오일', '치킨육수', '물'], ['계란', '양파', '당근', '밥', '청피망', '홍피망', '오이', '전분'], ['옥수수', '양파', '우유'], ['완두콩', '감자', '양파', '우유'], ['완두콩', '물', '감자', '버터', '밀가루', '생크림'], ['밥', '쇠고기', '양파', '당근', '감자', '사과', '오렌지', '옥수수', '버터', '카레', '물', '건포도'], ['토마토', '홍피망', '오이', '양파', '올리브오일', '물', '토마토주스', '크루통'], ['감자', '당근', '양파', '샐러리', '양송이버섯', '홀토마토', '물', '버터'], ['쇠고기스톡', '버터', '당근', '양파', '샐러리', '피망', '무'], ['밥', '닭고기', '감자', '양파', '피망', '치즈', '밀가루', '계란', '빵가루', '튀김기름'], ['닭', '카레', '밥', '식용유', '양송이버섯', '피망', '파프리카', '방울토마토', '꼬치'], ['밥', '쇠고기', '양파', '마늘', '토마토', '칠리', '프랑크소시지', '대파', '버터', '밀가루', '물'], ['스위트콘', '버터', '양파', '물', '우유', '생크림']]
# [['양파', '바게트빵', '마늘', '올리브오일', '치킨육수', '물'], ['계란', '양파', '당근', '밥', '청피망', '홍피망', '오이', '전분'], ['옥수수', '양파', '우유'], ['완두콩', '감자', '양파', '우유'], ['완두콩', '물', '감자', '버터', '밀가루', '생크림'], ['밥', '쇠고기', '양파', '당근', '감자', '사과', '오렌지', '옥수수', '버터', '카레', '물', '건포도'], ['토마토', '홍피망', '오이', '양파', '올리브오일', '물', '토마토주스', '크루통'], ['감자', '당근', '양파', '샐러리', '양송이버섯', '홀토마토', '물', '버터'], ['쇠고기스톡', '버터', '당근', '양파', '샐러리', '피망', '무'], ['밥', '닭고기', '감자', '양파', '피망', '치즈', '밀가루', '계란', '빵가루', '튀김기름'], ['닭', '카레', '밥', '식용유', '양송이버섯', '피망', '파프리카', '방울토마토', '꼬치'], ['밥', '쇠고기', '양파', '마늘', '토마토', '칠리', '프랑크소시지', '대파', '버터', '밀가루', '물'], ['스위트콘', '버터', '양파', '물', '우유', '생크림'], ['껍질콩', '물', '파슬리', '베이컨', '양상추', '비프스톡파우더', '버터', '밀가루', '옥수수통조림', '셀피유']]
# [['양파', '바게트빵', '마늘', '올리브오일', '치킨육수', '물'], ['계란', '양파', '당근', '밥', '청피망', '홍피망', '오이', '전분'], ['옥수수', '양파', '우유'], ['완두콩', '감자', '양파', '우유'], ['완두콩', '물', '감자', '버터', '밀가루', '생크림'], ['밥', '쇠고기', '양파', '당근', '감자', '사과', '오렌지', '옥수수', '버터', '카레', '물', '건포도'], ['토마토', '홍피망', '오이', '양파', '올리브오일', '물', '토마토주스', '크루통'], ['감자', '당근', '양파', '샐러리', '양송이버섯', '홀토마토', '물', '버터'], ['쇠고기스톡', '버터', '당근', '양파', '샐러리', '피망', '무'], ['밥', '닭고기', '감자', '양파', '피망', '치즈', '밀가루', '계란', '빵가루', '튀김기름'], ['닭', '카레', '밥', '식용유', '양송이버섯', '피망', '파프리카', '방울토마토', '꼬치'], ['밥', '쇠고기', '양파', '마늘', '토마토', '칠리', '프랑크소시지', '대파', '버터', '밀가루', '물'], ['스위트콘', '버터', '양파', '물', '우유', '생크림'], ['껍질콩', '물', '파슬리', '베이컨', '양상추', '비프스톡파우더', '버터', '밀가루', '옥수수통조림', '셀피유'], ['돼지고기', '양파', '밀가루']]
#                                                    재료
# 0                      [양파, 바게트빵, 마늘, 올리브오일, 치킨육수, 물]
# 1                   [계란, 양파, 당근, 밥, 청피망, 홍피망, 오이, 전분]
# 2                                       [옥수수, 양파, 우유]
# 3                                   [완두콩, 감자, 양파, 우유]
# 4                          [완두콩, 물, 감자, 버터, 밀가루, 생크림]
# 5   [밥, 쇠고기, 양파, 당근, 감자, 사과, 오렌지, 옥수수, 버터, 카레, 물, ...
# 6            [토마토, 홍피망, 오이, 양파, 올리브오일, 물, 토마토주스, 크루통]
# 7               [감자, 당근, 양파, 샐러리, 양송이버섯, 홀토마토, 물, 버터]
# 8                     [쇠고기스톡, 버터, 당근, 양파, 샐러리, 피망, 무]
# 9        [밥, 닭고기, 감자, 양파, 피망, 치즈, 밀가루, 계란, 빵가루, 튀김기름]
# 10        [닭, 카레, 밥, 식용유, 양송이버섯, 피망, 파프리카, 방울토마토, 꼬치]
# 11  [밥, 쇠고기, 양파, 마늘, 토마토, 칠리, 프랑크소시지, 대파, 버터, 밀가루, 물]
# 12                         [스위트콘, 버터, 양파, 물, 우유, 생크림]
# 13  [껍질콩, 물, 파슬리, 베이컨, 양상추, 비프스톡파우더, 버터, 밀가루, 옥수수통...
# 14                                    [돼지고기, 양파, 밀가루]
# [['참치', '양파', '마늘', '계란흰자', '밀가루', '튀김기름', '당근', '피망']]
# [['참치', '양파', '마늘', '계란흰자', '밀가루', '튀김기름', '당근', '피망'], ['토마토', '가지', '모짜렐라치즈']]
# [['참치', '양파', '마늘', '계란흰자', '밀가루', '튀김기름', '당근', '피망'], ['토마토', '가지', '모짜렐라치즈'], ['감자', '포도씨오일']]
# [['참치', '양파', '마늘', '계란흰자', '밀가루', '튀김기름', '당근', '피망'], ['토마토', '가지', '모짜렐라치즈'], ['감자', '포도씨오일'], ['감자', '치즈', '베이컨']]
# [['참치', '양파', '마늘', '계란흰자', '밀가루', '튀김기름', '당근', '피망'], ['토마토', '가지', '모짜렐라치즈'], ['감자', '포도씨오일'], ['감자', '치즈', '베이컨'], ['백립', '[재움액]', '생강', '통마늘', '월계수잎', '대파', '레드와인', '립삶은육수', '다진건포도', '커피']]
# [['참치', '양파', '마늘', '계란흰자', '밀가루', '튀김기름', '당근', '피망'], ['토마토', '가지', '모짜렐라치즈'], ['감자', '포도씨오일'], ['감자', '치즈', '베이컨'], ['백립', '[재움액]', '생강', '통마늘', '월계수잎', '대파', '레드와인', '립삶은육수', '다진건포도', '커피'], ['닭가슴살', '양상추', '각종유기농채소', '마늘', '소금', '통후추']]
# [['참치', '양파', '마늘', '계란흰자', '밀가루', '튀김기름', '당근', '피망'], ['토마토', '가지', '모짜렐라치즈'], ['감자', '포도씨오일'], ['감자', '치즈', '베이컨'], ['백립', '[재움액]', '생강', '통마늘', '월계수잎', '대파', '레드와인', '립삶은육수', '다진건포도', '커피'], ['닭가슴살', '양상추', '각종유기농채소', '마늘', '소금', '통후추'], ['대합', '양파', '청피망', '홍피망', '모짜렐라치즈']]
# [['참치', '양파', '마늘', '계란흰자', '밀가루', '튀김기름', '당근', '피망'], ['토마토', '가지', '모짜렐라치즈'], ['감자', '포도씨오일'], ['감자', '치즈', '베이컨'], ['백립', '[재움액]', '생강', '통마늘', '월계수잎', '대파', '레드와인', '립삶은육수', '다진건포도', '커피'], ['닭가슴살', '양상추', '각종유기농채소', '마늘', '소금', '통후추'], ['대합', '양파', '청피망', '홍피망', '모짜렐라치즈'], ['쇠고기', '양파', '당근', '호박', '감자', '가지', '샐러리']]
# [['참치', '양파', '마늘', '계란흰자', '밀가루', '튀김기름', '당근', '피망'], ['토마토', '가지', '모짜렐라치즈'], ['감자', '포도씨오일'], ['감자', '치즈', '베이컨'], ['백립', '[재움액]', '생강', '통마늘', '월계수잎', '대파', '레드와인', '립삶은육수', '다진건포도', '커피'], ['닭가슴살', '양상추', '각종유기농채소', '마늘', '소금', '통후추'], ['대합', '양파', '청피망', '홍피망', '모짜렐라치즈'], ['쇠고기', '양파', '당근', '호박', '감자', '가지', '샐러리'], ['대구', '홍피망', '가지', '양파', '양송이버섯', '토마토', '호박']]
# [['참치', '양파', '마늘', '계란흰자', '밀가루', '튀김기름', '당근', '피망'], ['토마토', '가지', '모짜렐라치즈'], ['감자', '포도씨오일'], ['감자', '치즈', '베이컨'], ['백립', '[재움액]', '생강', '통마늘', '월계수잎', '대파', '레드와인', '립삶은육수', '다진건포도', '커피'], ['닭가슴살', '양상추', '각종유기농채소', '마늘', '소금', '통후추'], ['대합', '양파', '청피망', '홍피망', '모짜렐라치즈'], ['쇠고기', '양파', '당근', '호박', '감자', '가지', '샐러리'], ['대구', '홍피망', '가지', '양파', '양송이버섯', '토마토', '호박'], ['연어', '버터', '레드', '페퍼콘', '어린채소']]
# [['참치', '양파', '마늘', '계란흰자', '밀가루', '튀김기름', '당근', '피망'], ['토마토', '가지', '모짜렐라치즈'], ['감자', '포도씨오일'], ['감자', '치즈', '베이컨'], ['백립', '[재움액]', '생강', '통마늘', '월계수잎', '대파', '레드와인', '립삶은육수', '다진건포도', '커피'], ['닭가슴살', '양상추', '각종유기농채소', '마늘', '소금', '통후추'], ['대합', '양파', '청피망', '홍피망', '모짜렐라치즈'], ['쇠고기', '양파', '당근', '호박', '감자', '가지', '샐러리'], ['대구', '홍피망', '가지', '양파', '양송이버섯', '토마토', '호박'], ['연어', '버터', '레드', '페퍼콘', '어린채소'], ['돼지갈비', '밀가루', '브랜디']]
# [['참치', '양파', '마늘', '계란흰자', '밀가루', '튀김기름', '당근', '피망'], ['토마토', '가지', '모짜렐라치즈'], ['감자', '포도씨오일'], ['감자', '치즈', '베이컨'], ['백립', '[재움액]', '생강', '통마늘', '월계수잎', '대파', '레드와인', '립삶은육수', '다진건포도', '커피'], ['닭가슴살', '양상추', '각종유기농채소', '마늘', '소금', '통후추'], ['대합', '양파', '청피망', '홍피망', '모짜렐라치즈'], ['쇠고기', '양파', '당근', '호박', '감자', '가지', '샐러리'], ['대구', '홍피망', '가지', '양파', '양송이버섯', '토마토', '호박'], ['연어', '버터', '레드', '페퍼콘', '어린채소'], ['돼지갈비', '밀가루', '브랜디'], ['닭다리', '양파', '베이컨', '마늘']]
# [['참치', '양파', '마늘', '계란흰자', '밀가루', '튀김기름', '당근', '피망'], ['토마토', '가지', '모짜렐라치즈'], ['감자', '포도씨오일'], ['감자', '치즈', '베이컨'], ['백립', '[재움액]', '생강', '통마늘', '월계수잎', '대파', '레드와인', '립삶은육수', '다진건포도', '커피'], ['닭가슴살', '양상추', '각종유기농채소', '마늘', '소금', '통후추'], ['대합', '양파', '청피망', '홍피망', '모짜렐라치즈'], ['쇠고기', '양파', '당근', '호박', '감자', '가지', '샐러리'], ['대구', '홍피망', '가지', '양파', '양송이버섯', '토마토', '호박'], ['연어', '버터', '레드', '페퍼콘', '어린채소'], ['돼지갈비', '밀가루', '브랜디'], ['닭다리', '양파', '베이컨', '마늘'], ['닭', '양파', '감자', '당근', '셀러리']]
# [['참치', '양파', '마늘', '계란흰자', '밀가루', '튀김기름', '당근', '피망'], ['토마토', '가지', '모짜렐라치즈'], ['감자', '포도씨오일'], ['감자', '치즈', '베이컨'], ['백립', '[재움액]', '생강', '통마늘', '월계수잎', '대파', '레드와인', '립삶은육수', '다진건포도', '커피'], ['닭가슴살', '양상추', '각종유기농채소', '마늘', '소금', '통후추'], ['대합', '양파', '청피망', '홍피망', '모짜렐라치즈'], ['쇠고기', '양파', '당근', '호박', '감자', '가지', '샐러리'], ['대구', '홍피망', '가지', '양파', '양송이버섯', '토마토', '호박'], ['연어', '버터', '레드', '페퍼콘', '어린채소'], ['돼지갈비', '밀가루', '브랜디'], ['닭다리', '양파', '베이컨', '마늘'], ['닭', '양파', '감자', '당근', '셀러리'], ['닭고기', '베이컨', '아메리칸치즈', '감자', '토마토', '실파', '브로콜리', '당근', '애호박']]
# [['참치', '양파', '마늘', '계란흰자', '밀가루', '튀김기름', '당근', '피망'], ['토마토', '가지', '모짜렐라치즈'], ['감자', '포도씨오일'], ['감자', '치즈', '베이컨'], ['백립', '[재움액]', '생강', '통마늘', '월계수잎', '대파', '레드와인', '립삶은육수', '다진건포도', '커피'], ['닭가슴살', '양상추', '각종유기농채소', '마늘', '소금', '통후추'], ['대합', '양파', '청피망', '홍피망', '모짜렐라치즈'], ['쇠고기', '양파', '당근', '호박', '감자', '가지', '샐러리'], ['대구', '홍피망', '가지', '양파', '양송이버섯', '토마토', '호박'], ['연어', '버터', '레드', '페퍼콘', '어린채소'], ['돼지갈비', '밀가루', '브랜디'], ['닭다리', '양파', '베이컨', '마늘'], ['닭', '양파', '감자', '당근', '셀러리'], ['닭고기', '베이컨', '아메리칸치즈', '감자', '토마토', '실파', '브로콜리', '당근', '애호박'], ['돼지등갈비', '샐러리', '양파', '마늘']]
#                                                    재료
# 0               [참치, 양파, 마늘, 계란흰자, 밀가루, 튀김기름, 당근, 피망]
# 1                                   [토마토, 가지, 모짜렐라치즈]
# 2                                         [감자, 포도씨오일]
# 3                                       [감자, 치즈, 베이컨]
# 4   [백립, [재움액], 생강, 통마늘, 월계수잎, 대파, 레드와인, 립삶은육수, 다진...
# 5                   [닭가슴살, 양상추, 각종유기농채소, 마늘, 소금, 통후추]
# 6                          [대합, 양파, 청피망, 홍피망, 모짜렐라치즈]
# 7                      [쇠고기, 양파, 당근, 호박, 감자, 가지, 샐러리]
# 8                   [대구, 홍피망, 가지, 양파, 양송이버섯, 토마토, 호박]
# 9                             [연어, 버터, 레드, 페퍼콘, 어린채소]
# 10                                   [돼지갈비, 밀가루, 브랜디]
# 11                                 [닭다리, 양파, 베이컨, 마늘]
# 12                               [닭, 양파, 감자, 당근, 셀러리]
# 13     [닭고기, 베이컨, 아메리칸치즈, 감자, 토마토, 실파, 브로콜리, 당근, 애호박]
# 14                               [돼지등갈비, 샐러리, 양파, 마늘]
# [['돼지갈비', '청양고추', '통후추', '월계수잎']]
# [['돼지갈비', '청양고추', '통후추', '월계수잎'], ['닭', '화이트와인', '소금', '후춧가루', '버터', '밀가루']]
# [['돼지갈비', '청양고추', '통후추', '월계수잎'], ['닭', '화이트와인', '소금', '후춧가루', '버터', '밀가루'], ['닭고기', '샐러리', '마요네즈', '레몬즙', '파마산치즈']]
# [['돼지갈비', '청양고추', '통후추', '월계수잎'], ['닭', '화이트와인', '소금', '후춧가루', '버터', '밀가루'], ['닭고기', '샐러리', '마요네즈', '레몬즙', '파마산치즈'], ['베이컨', '햄', '식용유']]
# [['돼지갈비', '청양고추', '통후추', '월계수잎'], ['닭', '화이트와인', '소금', '후춧가루', '버터', '밀가루'], ['닭고기', '샐러리', '마요네즈', '레몬즙', '파마산치즈'], ['베이컨', '햄', '식용유'], ['쇠고기', '당근', '양파', '청피망', '오이피클', '베이컨', '식용유', '밀가루', '홍피망']]
# [['돼지갈비', '청양고추', '통후추', '월계수잎'], ['닭', '화이트와인', '소금', '후춧가루', '버터', '밀가루'], ['닭고기', '샐러리', '마요네즈', '레몬즙', '파마산치즈'], ['베이컨', '햄', '식용유'], ['쇠고기', '당근', '양파', '청피망', '오이피클', '베이컨', '식용유', '밀가루', '홍피망'], ['새우', '양송이버섯', '청피망', '양파', '밥', '버터', '당근', '샐러리', '홍피망', '소금']]
# [['돼지갈비', '청양고추', '통후추', '월계수잎'], ['닭', '화이트와인', '소금', '후춧가루', '버터', '밀가루'], ['닭고기', '샐러리', '마요네즈', '레몬즙', '파마산치즈'], ['베이컨', '햄', '식용유'], ['쇠고기', '당근', '양파', '청피망', '오이피클', '베이컨', '식용유', '밀가루', '홍피망'], ['새우', '양송이버섯', '청피망', '양파', '밥', '버터', '당근', '샐러리', '홍피망', '소금'], ['감자', '버터', '우유', '후루츠칵테일', '은박컵']]
# [['돼지갈비', '청양고추', '통후추', '월계수잎'], ['닭', '화이트와인', '소금', '후춧가루', '버터', '밀가루'], ['닭고기', '샐러리', '마요네즈', '레몬즙', '파마산치즈'], ['베이컨', '햄', '식용유'], ['쇠고기', '당근', '양파', '청피망', '오이피클', '베이컨', '식용유', '밀가루', '홍피망'], ['새우', '양송이버섯', '청피망', '양파', '밥', '버터', '당근', '샐러리', '홍피망', '소금'], ['감자', '버터', '우유', '후루츠칵테일', '은박컵'], ['닭', '빵가루', '토마토', '양송이버섯', '감자', '당근', '브로콜리', '토마토소스']]
# [['돼지갈비', '청양고추', '통후추', '월계수잎'], ['닭', '화이트와인', '소금', '후춧가루', '버터', '밀가루'], ['닭고기', '샐러리', '마요네즈', '레몬즙', '파마산치즈'], ['베이컨', '햄', '식용유'], ['쇠고기', '당근', '양파', '청피망', '오이피클', '베이컨', '식용유', '밀가루', '홍피망'], ['새우', '양송이버섯', '청피망', '양파', '밥', '버터', '당근', '샐러리', '홍피망', '소금'], ['감자', '버터', '우유', '후루츠칵테일', '은박컵'], ['닭', '빵가루', '토마토', '양송이버섯', '감자', '당근', '브로콜리', '토마토소스'], ['아스파라거스', '메추리알', '베이컨', '꼬치']]
# [['돼지갈비', '청양고추', '통후추', '월계수잎'], ['닭', '화이트와인', '소금', '후춧가루', '버터', '밀가루'], ['닭고기', '샐러리', '마요네즈', '레몬즙', '파마산치즈'], ['베이컨', '햄', '식용유'], ['쇠고기', '당근', '양파', '청피망', '오이피클', '베이컨', '식용유', '밀가루', '홍피망'], ['새우', '양송이버섯', '청피망', '양파', '밥', '버터', '당근', '샐러리', '홍피망', '소금'], ['감자', '버터', '우유', '후루츠칵테일', '은박컵'], ['닭', '빵가루', '토마토', '양송이버섯', '감자', '당근', '브로콜리', '토마토소스'], ['아스파라거스', '메추리알', '베이컨', '꼬치'], ['양송이버섯', '쇠고기', '양파', '마늘', '치즈', '올리브오일', '파슬리']]
# [['돼지갈비', '청양고추', '통후추', '월계수잎'], ['닭', '화이트와인', '소금', '후춧가루', '버터', '밀가루'], ['닭고기', '샐러리', '마요네즈', '레몬즙', '파마산치즈'], ['베이컨', '햄', '식용유'], ['쇠고기', '당근', '양파', '청피망', '오이피클', '베이컨', '식용유', '밀가루', '홍피망'], ['새우', '양송이버섯', '청피망', '양파', '밥', '버터', '당근', '샐러리', '홍피망', '소금'], ['감자', '버터', '우유', '후루츠칵테일', '은박컵'], ['닭', '빵가루', '토마토', '양송이버섯', '감자', '당근', '브로콜리', '토마토소스'], ['아스파라거스', '메추리알', '베이컨', '꼬치'], ['양송이버섯', '쇠고기', '양파', '마늘', '치즈', '올리브오일', '파슬리'], ['계란', '다진쇠고기', '다진돼지고기', '양파', '빵가루', '쇠고기']]
# [['돼지갈비', '청양고추', '통후추', '월계수잎'], ['닭', '화이트와인', '소금', '후춧가루', '버터', '밀가루'], ['닭고기', '샐러리', '마요네즈', '레몬즙', '파마산치즈'], ['베이컨', '햄', '식용유'], ['쇠고기', '당근', '양파', '청피망', '오이피클', '베이컨', '식용유', '밀가루', '홍피망'], ['새우', '양송이버섯', '청피망', '양파', '밥', '버터', '당근', '샐러리', '홍피망', '소금'], ['감자', '버터', '우유', '후루츠칵테일', '은박컵'], ['닭', '빵가루', '토마토', '양송이버섯', '감자', '당근', '브로콜리', '토마토소스'], ['아스파라거스', '메추리알', '베이컨', '꼬치'], ['양송이버섯', '쇠고기', '양파', '마늘', '치즈', '올리브오일', '파슬리'], ['계란', '다진쇠고기', '다진돼지고기', '양파', '빵가루', '쇠고기'], ['미국산', '냉장', '목살']]
# [['돼지갈비', '청양고추', '통후추', '월계수잎'], ['닭', '화이트와인', '소금', '후춧가루', '버터', '밀가루'], ['닭고기', '샐러리', '마요네즈', '레몬즙', '파마산치즈'], ['베이컨', '햄', '식용유'], ['쇠고기', '당근', '양파', '청피망', '오이피클', '베이컨', '식용유', '밀가루', '홍피망'], ['새우', '양송이버섯', '청피망', '양파', '밥', '버터', '당근', '샐러리', '홍피망', '소금'], ['감자', '버터', '우유', '후루츠칵테일', '은박컵'], ['닭', '빵가루', '토마토', '양송이버섯', '감자', '당근', '브로콜리', '토마토소스'], ['아스파라거스', '메추리알', '베이컨', '꼬치'], ['양송이버섯', '쇠고기', '양파', '마늘', '치즈', '올리브오일', '파슬리'], ['계란', '다진쇠고기', '다진돼지고기', '양파', '빵가루', '쇠고기'], ['미국산', '냉장', '목살'], ['감자', '베이컨', '샤워크림']]
# [['돼지갈비', '청양고추', '통후추', '월계수잎'], ['닭', '화이트와인', '소금', '후춧가루', '버터', '밀가루'], ['닭고기', '샐러리', '마요네즈', '레몬즙', '파마산치즈'], ['베이컨', '햄', '식용유'], ['쇠고기', '당근', '양파', '청피망', '오이피클', '베이컨', '식용유', '밀가루', '홍피망'], ['새우', '양송이버섯', '청피망', '양파', '밥', '버터', '당근', '샐러리', '홍피망', '소금'], ['감자', '버터', '우유', '후루츠칵테일', '은박컵'], ['닭', '빵가루', '토마토', '양송이버섯', '감자', '당근', '브로콜리', '토마토소스'], ['아스파라거스', '메추리알', '베이컨', '꼬치'], ['양송이버섯', '쇠고기', '양파', '마늘', '치즈', '올리브오일', '파슬리'], ['계란', '다진쇠고기', '다진돼지고기', '양파', '빵가루', '쇠고기'], ['미국산', '냉장', '목살'], ['감자', '베이컨', '샤워크림'], ['고구마', '단호박', '가지', '당근', '통마늘', '식용유']]
# [['돼지갈비', '청양고추', '통후추', '월계수잎'], ['닭', '화이트와인', '소금', '후춧가루', '버터', '밀가루'], ['닭고기', '샐러리', '마요네즈', '레몬즙', '파마산치즈'], ['베이컨', '햄', '식용유'], ['쇠고기', '당근', '양파', '청피망', '오이피클', '베이컨', '식용유', '밀가루', '홍피망'], ['새우', '양송이버섯', '청피망', '양파', '밥', '버터', '당근', '샐러리', '홍피망', '소금'], ['감자', '버터', '우유', '후루츠칵테일', '은박컵'], ['닭', '빵가루', '토마토', '양송이버섯', '감자', '당근', '브로콜리', '토마토소스'], ['아스파라거스', '메추리알', '베이컨', '꼬치'], ['양송이버섯', '쇠고기', '양파', '마늘', '치즈', '올리브오일', '파슬리'], ['계란', '다진쇠고기', '다진돼지고기', '양파', '빵가루', '쇠고기'], ['미국산', '냉장', '목살'], ['감자', '베이컨', '샤워크림'], ['고구마', '단호박', '가지', '당근', '통마늘', '식용유'], ['오징어', '버터']]
#                                                재료
# 0                         [돼지갈비, 청양고추, 통후추, 월계수잎]
# 1                   [닭, 화이트와인, 소금, 후춧가루, 버터, 밀가루]
# 2                    [닭고기, 샐러리, 마요네즈, 레몬즙, 파마산치즈]
# 3                                   [베이컨, 햄, 식용유]
# 4    [쇠고기, 당근, 양파, 청피망, 오이피클, 베이컨, 식용유, 밀가루, 홍피망]
# 5   [새우, 양송이버섯, 청피망, 양파, 밥, 버터, 당근, 샐러리, 홍피망, 소금]
# 6                       [감자, 버터, 우유, 후루츠칵테일, 은박컵]
# 7       [닭, 빵가루, 토마토, 양송이버섯, 감자, 당근, 브로콜리, 토마토소스]
# 8                         [아스파라거스, 메추리알, 베이컨, 꼬치]
# 9            [양송이버섯, 쇠고기, 양파, 마늘, 치즈, 올리브오일, 파슬리]
# 10              [계란, 다진쇠고기, 다진돼지고기, 양파, 빵가루, 쇠고기]
# 11                                  [미국산, 냉장, 목살]
# 12                                [감자, 베이컨, 샤워크림]
# 13                   [고구마, 단호박, 가지, 당근, 통마늘, 식용유]
# 14                                      [오징어, 버터]
# [['도미', '감자', '화이트와인', '생크림', '양송이버섯', '양파', '가지', '토마토', '호박']]
# [['도미', '감자', '화이트와인', '생크림', '양송이버섯', '양파', '가지', '토마토', '호박'], ['대하', '아스파라거스', '새송이버섯', '느타리버섯', '애호박', '가지', '감자', '마늘']]
# [['도미', '감자', '화이트와인', '생크림', '양송이버섯', '양파', '가지', '토마토', '호박'], ['대하', '아스파라거스', '새송이버섯', '느타리버섯', '애호박', '가지', '감자', '마늘'], ['스타키스트참치통조림', '양송이버섯', '다진양파', '빵가루']]
# [['도미', '감자', '화이트와인', '생크림', '양송이버섯', '양파', '가지', '토마토', '호박'], ['대하', '아스파라거스', '새송이버섯', '느타리버섯', '애호박', '가지', '감자', '마늘'], ['스타키스트참치통조림', '양송이버섯', '다진양파', '빵가루'], ['쇠고기', '모짜렐라치즈', '카놀라유']]
# [['도미', '감자', '화이트와인', '생크림', '양송이버섯', '양파', '가지', '토마토', '호박'], ['대하', '아스파라거스', '새송이버섯', '느타리버섯', '애호박', '가지', '감자', '마늘'], ['스타키스트참치통조림', '양송이버섯', '다진양파', '빵가루'], ['쇠고기', '모짜렐라치즈', '카놀라유'], ['연어', '치즈', '양상추', '토마토', '래디쉬', '호박', '가지', '카놀라유']]
# [['도미', '감자', '화이트와인', '생크림', '양송이버섯', '양파', '가지', '토마토', '호박'], ['대하', '아스파라거스', '새송이버섯', '느타리버섯', '애호박', '가지', '감자', '마늘'], ['스타키스트참치통조림', '양송이버섯', '다진양파', '빵가루'], ['쇠고기', '모짜렐라치즈', '카놀라유'], ['연어', '치즈', '양상추', '토마토', '래디쉬', '호박', '가지', '카놀라유'], ['닭', '당근', '완두콩통조림', '옥수수통조림', '식용유', '버터']]
# [['도미', '감자', '화이트와인', '생크림', '양송이버섯', '양파', '가지', '토마토', '호박'], ['대하', '아스파라거스', '새송이버섯', '느타리버섯', '애호박', '가지', '감자', '마늘'], ['스타키스트참치통조림', '양송이버섯', '다진양파', '빵가루'], ['쇠고기', '모짜렐라치즈', '카놀라유'], ['연어', '치즈', '양상추', '토마토', '래디쉬', '호박', '가지', '카놀라유'], ['닭', '당근', '완두콩통조림', '옥수수통조림', '식용유', '버터'], ['옥수수통조림', '오이', '파프리카', '피자치즈']]
# [['도미', '감자', '화이트와인', '생크림', '양송이버섯', '양파', '가지', '토마토', '호박'], ['대하', '아스파라거스', '새송이버섯', '느타리버섯', '애호박', '가지', '감자', '마늘'], ['스타키스트참치통조림', '양송이버섯', '다진양파', '빵가루'], ['쇠고기', '모짜렐라치즈', '카놀라유'], ['연어', '치즈', '양상추', '토마토', '래디쉬', '호박', '가지', '카놀라유'], ['닭', '당근', '완두콩통조림', '옥수수통조림', '식용유', '버터'], ['옥수수통조림', '오이', '파프리카', '피자치즈'], ['옥수수통조림', '맛살', '당근', '피망', '피자치즈', '양파']]
# [['도미', '감자', '화이트와인', '생크림', '양송이버섯', '양파', '가지', '토마토', '호박'], ['대하', '아스파라거스', '새송이버섯', '느타리버섯', '애호박', '가지', '감자', '마늘'], ['스타키스트참치통조림', '양송이버섯', '다진양파', '빵가루'], ['쇠고기', '모짜렐라치즈', '카놀라유'], ['연어', '치즈', '양상추', '토마토', '래디쉬', '호박', '가지', '카놀라유'], ['닭', '당근', '완두콩통조림', '옥수수통조림', '식용유', '버터'], ['옥수수통조림', '오이', '파프리카', '피자치즈'], ['옥수수통조림', '맛살', '당근', '피망', '피자치즈', '양파'], ['닭고기', '버터', '올리브오일', '감자', '가지', '토마토', '다진마늘', '다진파슬리']]
# [['도미', '감자', '화이트와인', '생크림', '양송이버섯', '양파', '가지', '토마토', '호박'], ['대하', '아스파라거스', '새송이버섯', '느타리버섯', '애호박', '가지', '감자', '마늘'], ['스타키스트참치통조림', '양송이버섯', '다진양파', '빵가루'], ['쇠고기', '모짜렐라치즈', '카놀라유'], ['연어', '치즈', '양상추', '토마토', '래디쉬', '호박', '가지', '카놀라유'], ['닭', '당근', '완두콩통조림', '옥수수통조림', '식용유', '버터'], ['옥수수통조림', '오이', '파프리카', '피자치즈'], ['옥수수통조림', '맛살', '당근', '피망', '피자치즈', '양파'], ['닭고기', '버터', '올리브오일', '감자', '가지', '토마토', '다진마늘', '다진파슬리'], ['토마토', '양파', '청피망', '노랑', '파프리카', '모짜렐라치즈']]
# [['도미', '감자', '화이트와인', '생크림', '양송이버섯', '양파', '가지', '토마토', '호박'], ['대하', '아스파라거스', '새송이버섯', '느타리버섯', '애호박', '가지', '감자', '마늘'], ['스타키스트참치통조림', '양송이버섯', '다진양파', '빵가루'], ['쇠고기', '모짜렐라치즈', '카놀라유'], ['연어', '치즈', '양상추', '토마토', '래디쉬', '호박', '가지', '카놀라유'], ['닭', '당근', '완두콩통조림', '옥수수통조림', '식용유', '버터'], ['옥수수통조림', '오이', '파프리카', '피자치즈'], ['옥수수통조림', '맛살', '당근', '피망', '피자치즈', '양파'], ['닭고기', '버터', '올리브오일', '감자', '가지', '토마토', '다진마늘', '다진파슬리'], ['토마토', '양파', '청피망', '노랑', '파프리카', '모짜렐라치즈'], ['돼지고기', '식용유', '청피망']]
# [['도미', '감자', '화이트와인', '생크림', '양송이버섯', '양파', '가지', '토마토', '호박'], ['대하', '아스파라거스', '새송이버섯', '느타리버섯', '애호박', '가지', '감자', '마늘'], ['스타키스트참치통조림', '양송이버섯', '다진양파', '빵가루'], ['쇠고기', '모짜렐라치즈', '카놀라유'], ['연어', '치즈', '양상추', '토마토', '래디쉬', '호박', '가지', '카놀라유'], ['닭', '당근', '완두콩통조림', '옥수수통조림', '식용유', '버터'], ['옥수수통조림', '오이', '파프리카', '피자치즈'], ['옥수수통조림', '맛살', '당근', '피망', '피자치즈', '양파'], ['닭고기', '버터', '올리브오일', '감자', '가지', '토마토', '다진마늘', '다진파슬리'], ['토마토', '양파', '청피망', '노랑', '파프리카', '모짜렐라치즈'], ['돼지고기', '식용유', '청피망'], ['햄', '감자', '옥수수', '양송이버섯', '피자치즈', '버터']]
# [['도미', '감자', '화이트와인', '생크림', '양송이버섯', '양파', '가지', '토마토', '호박'], ['대하', '아스파라거스', '새송이버섯', '느타리버섯', '애호박', '가지', '감자', '마늘'], ['스타키스트참치통조림', '양송이버섯', '다진양파', '빵가루'], ['쇠고기', '모짜렐라치즈', '카놀라유'], ['연어', '치즈', '양상추', '토마토', '래디쉬', '호박', '가지', '카놀라유'], ['닭', '당근', '완두콩통조림', '옥수수통조림', '식용유', '버터'], ['옥수수통조림', '오이', '파프리카', '피자치즈'], ['옥수수통조림', '맛살', '당근', '피망', '피자치즈', '양파'], ['닭고기', '버터', '올리브오일', '감자', '가지', '토마토', '다진마늘', '다진파슬리'], ['토마토', '양파', '청피망', '노랑', '파프리카', '모짜렐라치즈'], ['돼지고기', '식용유', '청피망'], ['햄', '감자', '옥수수', '양송이버섯', '피자치즈', '버터'], ['다진쇠고기', '다진돼지고기', '양파', '빵가루', '버터', '육수', '계란', '식용유']]
# [['도미', '감자', '화이트와인', '생크림', '양송이버섯', '양파', '가지', '토마토', '호박'], ['대하', '아스파라거스', '새송이버섯', '느타리버섯', '애호박', '가지', '감자', '마늘'], ['스타키스트참치통조림', '양송이버섯', '다진양파', '빵가루'], ['쇠고기', '모짜렐라치즈', '카놀라유'], ['연어', '치즈', '양상추', '토마토', '래디쉬', '호박', '가지', '카놀라유'], ['닭', '당근', '완두콩통조림', '옥수수통조림', '식용유', '버터'], ['옥수수통조림', '오이', '파프리카', '피자치즈'], ['옥수수통조림', '맛살', '당근', '피망', '피자치즈', '양파'], ['닭고기', '버터', '올리브오일', '감자', '가지', '토마토', '다진마늘', '다진파슬리'], ['토마토', '양파', '청피망', '노랑', '파프리카', '모짜렐라치즈'], ['돼지고기', '식용유', '청피망'], ['햄', '감자', '옥수수', '양송이버섯', '피자치즈', '버터'], ['다진쇠고기', '다진돼지고기', '양파', '빵가루', '버터', '육수', '계란', '식용유'], ['홍합', '빵가루', '생크림', '홍고추', '청고추', '파마산치즈']]
# [['도미', '감자', '화이트와인', '생크림', '양송이버섯', '양파', '가지', '토마토', '호박'], ['대하', '아스파라거스', '새송이버섯', '느타리버섯', '애호박', '가지', '감자', '마늘'], ['스타키스트참치통조림', '양송이버섯', '다진양파', '빵가루'], ['쇠고기', '모짜렐라치즈', '카놀라유'], ['연어', '치즈', '양상추', '토마토', '래디쉬', '호박', '가지', '카놀라유'], ['닭', '당근', '완두콩통조림', '옥수수통조림', '식용유', '버터'], ['옥수수통조림', '오이', '파프리카', '피자치즈'], ['옥수수통조림', '맛살', '당근', '피망', '피자치즈', '양파'], ['닭고기', '버터', '올리브오일', '감자', '가지', '토마토', '다진마늘', '다진파슬리'], ['토마토', '양파', '청피망', '노랑', '파프리카', '모짜렐라치즈'], ['돼지고기', '식용유', '청피망'], ['햄', '감자', '옥수수', '양송이버섯', '피자치즈', '버터'], ['다진쇠고기', '다진돼지고기', '양파', '빵가루', '버터', '육수', '계란', '식용유'], ['홍합', '빵가루', '생크림', '홍고추', '청고추', '파마산치즈'], ['홍합', '모짜렐라치즈', '파슬리가루']]
#                                               재료
# 0   [도미, 감자, 화이트와인, 생크림, 양송이버섯, 양파, 가지, 토마토, 호박]
# 1    [대하, 아스파라거스, 새송이버섯, 느타리버섯, 애호박, 가지, 감자, 마늘]
# 2                 [스타키스트참치통조림, 양송이버섯, 다진양파, 빵가루]
# 3                            [쇠고기, 모짜렐라치즈, 카놀라유]
# 4          [연어, 치즈, 양상추, 토마토, 래디쉬, 호박, 가지, 카놀라유]
# 5               [닭, 당근, 완두콩통조림, 옥수수통조림, 식용유, 버터]
# 6                       [옥수수통조림, 오이, 파프리카, 피자치즈]
# 7                 [옥수수통조림, 맛살, 당근, 피망, 피자치즈, 양파]
# 8     [닭고기, 버터, 올리브오일, 감자, 가지, 토마토, 다진마늘, 다진파슬리]
# 9               [토마토, 양파, 청피망, 노랑, 파프리카, 모짜렐라치즈]
# 10                              [돼지고기, 식용유, 청피망]
# 11                 [햄, 감자, 옥수수, 양송이버섯, 피자치즈, 버터]
# 12     [다진쇠고기, 다진돼지고기, 양파, 빵가루, 버터, 육수, 계란, 식용유]
# 13               [홍합, 빵가루, 생크림, 홍고추, 청고추, 파마산치즈]
# 14                           [홍합, 모짜렐라치즈, 파슬리가루]
# [['감자', '양파', '다진쇠고기', '밀가루', '계란', '빵가루', '식용유']]
# [['감자', '양파', '다진쇠고기', '밀가루', '계란', '빵가루', '식용유'], ['고구마', '양파', '피망', '베이컨', '버터', '밀가루', '빵가루', '계란']]
# [['감자', '양파', '다진쇠고기', '밀가루', '계란', '빵가루', '식용유'], ['고구마', '양파', '피망', '베이컨', '버터', '밀가루', '빵가루', '계란'], ['고등어', '전분', '식용유', '양상추']]
# [['감자', '양파', '다진쇠고기', '밀가루', '계란', '빵가루', '식용유'], ['고구마', '양파', '피망', '베이컨', '버터', '밀가루', '빵가루', '계란'], ['고등어', '전분', '식용유', '양상추'], ['새우', '밀가루', '코코넛', '가루', '레몬', '오렌지', '마멀레이드', '계란', '하우스시즈닝', '베이킹파우더', '맥주']]
# [['감자', '양파', '다진쇠고기', '밀가루', '계란', '빵가루', '식용유'], ['고구마', '양파', '피망', '베이컨', '버터', '밀가루', '빵가루', '계란'], ['고등어', '전분', '식용유', '양상추'], ['새우', '밀가루', '코코넛', '가루', '레몬', '오렌지', '마멀레이드', '계란', '하우스시즈닝', '베이킹파우더', '맥주'], ['닭', '밀가루', '계란', '검은깨', '아몬드', '빵가루', '튀김기름']]
# [['감자', '양파', '다진쇠고기', '밀가루', '계란', '빵가루', '식용유'], ['고구마', '양파', '피망', '베이컨', '버터', '밀가루', '빵가루', '계란'], ['고등어', '전분', '식용유', '양상추'], ['새우', '밀가루', '코코넛', '가루', '레몬', '오렌지', '마멀레이드', '계란', '하우스시즈닝', '베이킹파우더', '맥주'], ['닭', '밀가루', '계란', '검은깨', '아몬드', '빵가루', '튀김기름'], ['닭', '식용유', '녹말가루', '튀김가루']]
# [['감자', '양파', '다진쇠고기', '밀가루', '계란', '빵가루', '식용유'], ['고구마', '양파', '피망', '베이컨', '버터', '밀가루', '빵가루', '계란'], ['고등어', '전분', '식용유', '양상추'], ['새우', '밀가루', '코코넛', '가루', '레몬', '오렌지', '마멀레이드', '계란', '하우스시즈닝', '베이킹파우더', '맥주'], ['닭', '밀가루', '계란', '검은깨', '아몬드', '빵가루', '튀김기름'], ['닭', '식용유', '녹말가루', '튀김가루'], ['돼지고기', '계란', '밀가루', '빵가루', '베이비콘', '스위트콘', '감자']]
# [['감자', '양파', '다진쇠고기', '밀가루', '계란', '빵가루', '식용유'], ['고구마', '양파', '피망', '베이컨', '버터', '밀가루', '빵가루', '계란'], ['고등어', '전분', '식용유', '양상추'], ['새우', '밀가루', '코코넛', '가루', '레몬', '오렌지', '마멀레이드', '계란', '하우스시즈닝', '베이킹파우더', '맥주'], ['닭', '밀가루', '계란', '검은깨', '아몬드', '빵가루', '튀김기름'], ['닭', '식용유', '녹말가루', '튀김가루'], ['돼지고기', '계란', '밀가루', '빵가루', '베이비콘', '스위트콘', '감자'], ['돼지고기', '치즈', '청피망', '홍피망', '계란', '밀가루', '빵가루', '식용유']]
# [['감자', '양파', '다진쇠고기', '밀가루', '계란', '빵가루', '식용유'], ['고구마', '양파', '피망', '베이컨', '버터', '밀가루', '빵가루', '계란'], ['고등어', '전분', '식용유', '양상추'], ['새우', '밀가루', '코코넛', '가루', '레몬', '오렌지', '마멀레이드', '계란', '하우스시즈닝', '베이킹파우더', '맥주'], ['닭', '밀가루', '계란', '검은깨', '아몬드', '빵가루', '튀김기름'], ['닭', '식용유', '녹말가루', '튀김가루'], ['돼지고기', '계란', '밀가루', '빵가루', '베이비콘', '스위트콘', '감자'], ['돼지고기', '치즈', '청피망', '홍피망', '계란', '밀가루', '빵가루', '식용유'], ['닭', '계란', '녹말', '빵가루']]
# [['감자', '양파', '다진쇠고기', '밀가루', '계란', '빵가루', '식용유'], ['고구마', '양파', '피망', '베이컨', '버터', '밀가루', '빵가루', '계란'], ['고등어', '전분', '식용유', '양상추'], ['새우', '밀가루', '코코넛', '가루', '레몬', '오렌지', '마멀레이드', '계란', '하우스시즈닝', '베이킹파우더', '맥주'], ['닭', '밀가루', '계란', '검은깨', '아몬드', '빵가루', '튀김기름'], ['닭', '식용유', '녹말가루', '튀김가루'], ['돼지고기', '계란', '밀가루', '빵가루', '베이비콘', '스위트콘', '감자'], ['돼지고기', '치즈', '청피망', '홍피망', '계란', '밀가루', '빵가루', '식용유'], ['닭', '계란', '녹말', '빵가루'], ['모짜렐라치즈', '밀가루', '계란', '빵가루', '식용유']]
# [['감자', '양파', '다진쇠고기', '밀가루', '계란', '빵가루', '식용유'], ['고구마', '양파', '피망', '베이컨', '버터', '밀가루', '빵가루', '계란'], ['고등어', '전분', '식용유', '양상추'], ['새우', '밀가루', '코코넛', '가루', '레몬', '오렌지', '마멀레이드', '계란', '하우스시즈닝', '베이킹파우더', '맥주'], ['닭', '밀가루', '계란', '검은깨', '아몬드', '빵가루', '튀김기름'], ['닭', '식용유', '녹말가루', '튀김가루'], ['돼지고기', '계란', '밀가루', '빵가루', '베이비콘', '스위트콘', '감자'], ['돼지고기', '치즈', '청피망', '홍피망', '계란', '밀가루', '빵가루', '식용유'], ['닭', '계란', '녹말', '빵가루'], ['모짜렐라치즈', '밀가루', '계란', '빵가루', '식용유'], ['모짜렐라치즈', '계란', '밀가루', '빵가루', '튀김기름']]
# [['감자', '양파', '다진쇠고기', '밀가루', '계란', '빵가루', '식용유'], ['고구마', '양파', '피망', '베이컨', '버터', '밀가루', '빵가루', '계란'], ['고등어', '전분', '식용유', '양상추'], ['새우', '밀가루', '코코넛', '가루', '레몬', '오렌지', '마멀레이드', '계란', '하우스시즈닝', '베이킹파우더', '맥주'], ['닭', '밀가루', '계란', '검은깨', '아몬드', '빵가루', '튀김기름'], ['닭', '식용유', '녹말가루', '튀김가루'], ['돼지고기', '계란', '밀가루', '빵가루', '베이비콘', '스위트콘', '감자'], ['돼지고기', '치즈', '청피망', '홍피망', '계란', '밀가루', '빵가루', '식용유'], ['닭', '계란', '녹말', '빵가루'], ['모짜렐라치즈', '밀가루', '계란', '빵가루', '식용유'], ['모짜렐라치즈', '계란', '밀가루', '빵가루', '튀김기름'], ['포도씨유', '비엔나소시지', '빵가루', '밀가루', '계란', '우유']]
# [['감자', '양파', '다진쇠고기', '밀가루', '계란', '빵가루', '식용유'], ['고구마', '양파', '피망', '베이컨', '버터', '밀가루', '빵가루', '계란'], ['고등어', '전분', '식용유', '양상추'], ['새우', '밀가루', '코코넛', '가루', '레몬', '오렌지', '마멀레이드', '계란', '하우스시즈닝', '베이킹파우더', '맥주'], ['닭', '밀가루', '계란', '검은깨', '아몬드', '빵가루', '튀김기름'], ['닭', '식용유', '녹말가루', '튀김가루'], ['돼지고기', '계란', '밀가루', '빵가루', '베이비콘', '스위트콘', '감자'], ['돼지고기', '치즈', '청피망', '홍피망', '계란', '밀가루', '빵가루', '식용유'], ['닭', '계란', '녹말', '빵가루'], ['모짜렐라치즈', '밀가루', '계란', '빵가루', '식용유'], ['모짜렐라치즈', '계란', '밀가루', '빵가루', '튀김기름'], ['포도씨유', '비엔나소시지', '빵가루', '밀가루', '계란', '우유'], ['베이컨', '메추리알', '계란', '밀가루', '빵가루', '튀김기름']]
# [['감자', '양파', '다진쇠고기', '밀가루', '계란', '빵가루', '식용유'], ['고구마', '양파', '피망', '베이컨', '버터', '밀가루', '빵가루', '계란'], ['고등어', '전분', '식용유', '양상추'], ['새우', '밀가루', '코코넛', '가루', '레몬', '오렌지', '마멀레이드', '계란', '하우스시즈닝', '베이킹파우더', '맥주'], ['닭', '밀가루', '계란', '검은깨', '아몬드', '빵가루', '튀김기름'], ['닭', '식용유', '녹말가루', '튀김가루'], ['돼지고기', '계란', '밀가루', '빵가루', '베이비콘', '스위트콘', '감자'], ['돼지고기', '치즈', '청피망', '홍피망', '계란', '밀가루', '빵가루', '식용유'], ['닭', '계란', '녹말', '빵가루'], ['모짜렐라치즈', '밀가루', '계란', '빵가루', '식용유'], ['모짜렐라치즈', '계란', '밀가루', '빵가루', '튀김기름'], ['포도씨유', '비엔나소시지', '빵가루', '밀가루', '계란', '우유'], ['베이컨', '메추리알', '계란', '밀가루', '빵가루', '튀김기름'], ['삼겹살', '청피망', '양송이버섯', '홍피망', '계란', '치즈', '밀가루', '빵가루', '식용유']]
# [['감자', '양파', '다진쇠고기', '밀가루', '계란', '빵가루', '식용유'], ['고구마', '양파', '피망', '베이컨', '버터', '밀가루', '빵가루', '계란'], ['고등어', '전분', '식용유', '양상추'], ['새우', '밀가루', '코코넛', '가루', '레몬', '오렌지', '마멀레이드', '계란', '하우스시즈닝', '베이킹파우더', '맥주'], ['닭', '밀가루', '계란', '검은깨', '아몬드', '빵가루', '튀김기름'], ['닭', '식용유', '녹말가루', '튀김가루'], ['돼지고기', '계란', '밀가루', '빵가루', '베이비콘', '스위트콘', '감자'], ['돼지고기', '치즈', '청피망', '홍피망', '계란', '밀가루', '빵가루', '식용유'], ['닭', '계란', '녹말', '빵가루'], ['모짜렐라치즈', '밀가루', '계란', '빵가루', '식용유'], ['모짜렐라치즈', '계란', '밀가루', '빵가루', '튀김기름'], ['포도씨유', '비엔나소시지', '빵가루', '밀가루', '계란', '우유'], ['베이컨', '메추리알', '계란', '밀가루', '빵가루', '튀김기름'], ['삼겹살', '청피망', '양송이버섯', '홍피망', '계란', '치즈', '밀가루', '빵가루', '식용유'], ['쇠고기', '치즈', '계란', '밀가루', '빵가루']]
#                                                    재료
# 0                  [감자, 양파, 다진쇠고기, 밀가루, 계란, 빵가루, 식용유]
# 1                [고구마, 양파, 피망, 베이컨, 버터, 밀가루, 빵가루, 계란]
# 2                                 [고등어, 전분, 식용유, 양상추]
# 3   [새우, 밀가루, 코코넛, 가루, 레몬, 오렌지, 마멀레이드, 계란, 하우스시즈닝,...
# 4                   [닭, 밀가루, 계란, 검은깨, 아몬드, 빵가루, 튀김기름]
# 5                                [닭, 식용유, 녹말가루, 튀김가루]
# 6                [돼지고기, 계란, 밀가루, 빵가루, 베이비콘, 스위트콘, 감자]
# 7             [돼지고기, 치즈, 청피망, 홍피망, 계란, 밀가루, 빵가루, 식용유]
# 8                                    [닭, 계란, 녹말, 빵가루]
# 9                         [모짜렐라치즈, 밀가루, 계란, 빵가루, 식용유]
# 10                       [모짜렐라치즈, 계란, 밀가루, 빵가루, 튀김기름]
# 11                   [포도씨유, 비엔나소시지, 빵가루, 밀가루, 계란, 우유]
# 12                    [베이컨, 메추리알, 계란, 밀가루, 빵가루, 튀김기름]
# 13      [삼겹살, 청피망, 양송이버섯, 홍피망, 계란, 치즈, 밀가루, 빵가루, 식용유]
# 14                            [쇠고기, 치즈, 계란, 밀가루, 빵가루]
# [['쇠고기', '모짜렐라치즈', '홍고추', '청고추', '밀가루', '계란', '빵가루', '치즈', '튀김기름', '레몬']]
# [['쇠고기', '모짜렐라치즈', '홍고추', '청고추', '밀가루', '계란', '빵가루', '치즈', '튀김기름', '레몬'], ['식빵', '피자치즈', '식용유']]
# [['쇠고기', '모짜렐라치즈', '홍고추', '청고추', '밀가루', '계란', '빵가루', '치즈', '튀김기름', '레몬'], ['식빵', '피자치즈', '식용유'], ['양파', '홍고추', '청고추', '밀가루', '계란', '빵가루']]
# [['쇠고기', '모짜렐라치즈', '홍고추', '청고추', '밀가루', '계란', '빵가루', '치즈', '튀김기름', '레몬'], ['식빵', '피자치즈', '식용유'], ['양파', '홍고추', '청고추', '밀가루', '계란', '빵가루'], ['스위트콘', '햄', '표고버섯', '양파', '계란', '슬라이스치즈', '오이', '당근']]
# [['쇠고기', '모짜렐라치즈', '홍고추', '청고추', '밀가루', '계란', '빵가루', '치즈', '튀김기름', '레몬'], ['식빵', '피자치즈', '식용유'], ['양파', '홍고추', '청고추', '밀가루', '계란', '빵가루'], ['스위트콘', '햄', '표고버섯', '양파', '계란', '슬라이스치즈', '오이', '당근'], ['감자', '오이', '양파', '치즈', '밀가루', '빵가루', '계란', '스위트콘']]
# [['쇠고기', '모짜렐라치즈', '홍고추', '청고추', '밀가루', '계란', '빵가루', '치즈', '튀김기름', '레몬'], ['식빵', '피자치즈', '식용유'], ['양파', '홍고추', '청고추', '밀가루', '계란', '빵가루'], ['스위트콘', '햄', '표고버섯', '양파', '계란', '슬라이스치즈', '오이', '당근'], ['감자', '오이', '양파', '치즈', '밀가루', '빵가루', '계란', '스위트콘'], ['돼지고기', '모짜렐라치즈', '청피망', '밀가루', '계란', '빵가루']]
# [['쇠고기', '모짜렐라치즈', '홍고추', '청고추', '밀가루', '계란', '빵가루', '치즈', '튀김기름', '레몬'], ['식빵', '피자치즈', '식용유'], ['양파', '홍고추', '청고추', '밀가루', '계란', '빵가루'], ['스위트콘', '햄', '표고버섯', '양파', '계란', '슬라이스치즈', '오이', '당근'], ['감자', '오이', '양파', '치즈', '밀가루', '빵가루', '계란', '스위트콘'], ['돼지고기', '모짜렐라치즈', '청피망', '밀가루', '계란', '빵가루'], ['계란흰자', '피자치즈', '밀가루', '넛맥', '식용유']]
# [['쇠고기', '모짜렐라치즈', '홍고추', '청고추', '밀가루', '계란', '빵가루', '치즈', '튀김기름', '레몬'], ['식빵', '피자치즈', '식용유'], ['양파', '홍고추', '청고추', '밀가루', '계란', '빵가루'], ['스위트콘', '햄', '표고버섯', '양파', '계란', '슬라이스치즈', '오이', '당근'], ['감자', '오이', '양파', '치즈', '밀가루', '빵가루', '계란', '스위트콘'], ['돼지고기', '모짜렐라치즈', '청피망', '밀가루', '계란', '빵가루'], ['계란흰자', '피자치즈', '밀가루', '넛맥', '식용유'], ['닭안심', '밀가루', '계란', '빵가루']]
# [['쇠고기', '모짜렐라치즈', '홍고추', '청고추', '밀가루', '계란', '빵가루', '치즈', '튀김기름', '레몬'], ['식빵', '피자치즈', '식용유'], ['양파', '홍고추', '청고추', '밀가루', '계란', '빵가루'], ['스위트콘', '햄', '표고버섯', '양파', '계란', '슬라이스치즈', '오이', '당근'], ['감자', '오이', '양파', '치즈', '밀가루', '빵가루', '계란', '스위트콘'], ['돼지고기', '모짜렐라치즈', '청피망', '밀가루', '계란', '빵가루'], ['계란흰자', '피자치즈', '밀가루', '넛맥', '식용유'], ['닭안심', '밀가루', '계란', '빵가루'], ['참치통조림', '양파', '청피망', '두부', '홍피망', '계란노른자', '빵가루']]
# [['쇠고기', '모짜렐라치즈', '홍고추', '청고추', '밀가루', '계란', '빵가루', '치즈', '튀김기름', '레몬'], ['식빵', '피자치즈', '식용유'], ['양파', '홍고추', '청고추', '밀가루', '계란', '빵가루'], ['스위트콘', '햄', '표고버섯', '양파', '계란', '슬라이스치즈', '오이', '당근'], ['감자', '오이', '양파', '치즈', '밀가루', '빵가루', '계란', '스위트콘'], ['돼지고기', '모짜렐라치즈', '청피망', '밀가루', '계란', '빵가루'], ['계란흰자', '피자치즈', '밀가루', '넛맥', '식용유'], ['닭안심', '밀가루', '계란', '빵가루'], ['참치통조림', '양파', '청피망', '두부', '홍피망', '계란노른자', '빵가루'], ['흰밥', '프랑크소시지', '밀가루', '계란', '빵가루', '버터', '카레가루']]
# [['쇠고기', '모짜렐라치즈', '홍고추', '청고추', '밀가루', '계란', '빵가루', '치즈', '튀김기름', '레몬'], ['식빵', '피자치즈', '식용유'], ['양파', '홍고추', '청고추', '밀가루', '계란', '빵가루'], ['스위트콘', '햄', '표고버섯', '양파', '계란', '슬라이스치즈', '오이', '당근'], ['감자', '오이', '양파', '치즈', '밀가루', '빵가루', '계란', '스위트콘'], ['돼지고기', '모짜렐라치즈', '청피망', '밀가루', '계란', '빵가루'], ['계란흰자', '피자치즈', '밀가루', '넛맥', '식용유'], ['닭안심', '밀가루', '계란', '빵가루'], ['참치통조림', '양파', '청피망', '두부', '홍피망', '계란노른자', '빵가루'], ['흰밥', '프랑크소시지', '밀가루', '계란', '빵가루', '버터', '카레가루'], ['밀가루', '드라이이스트', '설탕', '소금', '분유', '계란', '물', '버터']]
# [['쇠고기', '모짜렐라치즈', '홍고추', '청고추', '밀가루', '계란', '빵가루', '치즈', '튀김기름', '레몬'], ['식빵', '피자치즈', '식용유'], ['양파', '홍고추', '청고추', '밀가루', '계란', '빵가루'], ['스위트콘', '햄', '표고버섯', '양파', '계란', '슬라이스치즈', '오이', '당근'], ['감자', '오이', '양파', '치즈', '밀가루', '빵가루', '계란', '스위트콘'], ['돼지고기', '모짜렐라치즈', '청피망', '밀가루', '계란', '빵가루'], ['계란흰자', '피자치즈', '밀가루', '넛맥', '식용유'], ['닭안심', '밀가루', '계란', '빵가루'], ['참치통조림', '양파', '청피망', '두부', '홍피망', '계란노른자', '빵가루'], ['흰밥', '프랑크소시지', '밀가루', '계란', '빵가루', '버터', '카레가루'], ['밀가루', '드라이이스트', '설탕', '소금', '분유', '계란', '물', '버터'], ['새우', '고등어', '굴비', '갈치', '빵가루', '계란', '밀가루', '오렌지', '방울토마토']]
# [['쇠고기', '모짜렐라치즈', '홍고추', '청고추', '밀가루', '계란', '빵가루', '치즈', '튀김기름', '레몬'], ['식빵', '피자치즈', '식용유'], ['양파', '홍고추', '청고추', '밀가루', '계란', '빵가루'], ['스위트콘', '햄', '표고버섯', '양파', '계란', '슬라이스치즈', '오이', '당근'], ['감자', '오이', '양파', '치즈', '밀가루', '빵가루', '계란', '스위트콘'], ['돼지고기', '모짜렐라치즈', '청피망', '밀가루', '계란', '빵가루'], ['계란흰자', '피자치즈', '밀가루', '넛맥', '식용유'], ['닭안심', '밀가루', '계란', '빵가루'], ['참치통조림', '양파', '청피망', '두부', '홍피망', '계란노른자', '빵가루'], ['흰밥', '프랑크소시지', '밀가루', '계란', '빵가루', '버터', '카레가루'], ['밀가루', '드라이이스트', '설탕', '소금', '분유', '계란', '물', '버터'], ['새우', '고등어', '굴비', '갈치', '빵가루', '계란', '밀가루', '오렌지', '방울토마토'], ['토마토', '빵가루', '다진올리브', '다진파슬리', '샐러드오일']]
# [['쇠고기', '모짜렐라치즈', '홍고추', '청고추', '밀가루', '계란', '빵가루', '치즈', '튀김기름', '레몬'], ['식빵', '피자치즈', '식용유'], ['양파', '홍고추', '청고추', '밀가루', '계란', '빵가루'], ['스위트콘', '햄', '표고버섯', '양파', '계란', '슬라이스치즈', '오이', '당근'], ['감자', '오이', '양파', '치즈', '밀가루', '빵가루', '계란', '스위트콘'], ['돼지고기', '모짜렐라치즈', '청피망', '밀가루', '계란', '빵가루'], ['계란흰자', '피자치즈', '밀가루', '넛맥', '식용유'], ['닭안심', '밀가루', '계란', '빵가루'], ['참치통조림', '양파', '청피망', '두부', '홍피망', '계란노른자', '빵가루'], ['흰밥', '프랑크소시지', '밀가루', '계란', '빵가루', '버터', '카레가루'], ['밀가루', '드라이이스트', '설탕', '소금', '분유', '계란', '물', '버터'], ['새우', '고등어', '굴비', '갈치', '빵가루', '계란', '밀가루', '오렌지', '방울토마토'], ['토마토', '빵가루', '다진올리브', '다진파슬리', '샐러드오일'], ['돼지고기', '양파', '청피망', '슬라이스치즈', '피자치즈', '피자소스', '밀가루', '계란', '빵가루', '식용유', '홍피망']]
# [['쇠고기', '모짜렐라치즈', '홍고추', '청고추', '밀가루', '계란', '빵가루', '치즈', '튀김기름', '레몬'], ['식빵', '피자치즈', '식용유'], ['양파', '홍고추', '청고추', '밀가루', '계란', '빵가루'], ['스위트콘', '햄', '표고버섯', '양파', '계란', '슬라이스치즈', '오이', '당근'], ['감자', '오이', '양파', '치즈', '밀가루', '빵가루', '계란', '스위트콘'], ['돼지고기', '모짜렐라치즈', '청피망', '밀가루', '계란', '빵가루'], ['계란흰자', '피자치즈', '밀가루', '넛맥', '식용유'], ['닭안심', '밀가루', '계란', '빵가루'], ['참치통조림', '양파', '청피망', '두부', '홍피망', '계란노른자', '빵가루'], ['흰밥', '프랑크소시지', '밀가루', '계란', '빵가루', '버터', '카레가루'], ['밀가루', '드라이이스트', '설탕', '소금', '분유', '계란', '물', '버터'], ['새우', '고등어', '굴비', '갈치', '빵가루', '계란', '밀가루', '오렌지', '방울토마토'], ['토마토', '빵가루', '다진올리브', '다진파슬리', '샐러드오일'], ['돼지고기', '양파', '청피망', '슬라이스치즈', '피자치즈', '피자소스', '밀가루', '계란', '빵가루', '식용유', '홍피망'], ['고등어', '오렌지', '샐러리', '허브', '빵가루', '밀가루', '계란', '계란노른자']]
#                                                    재료
# 0   [쇠고기, 모짜렐라치즈, 홍고추, 청고추, 밀가루, 계란, 빵가루, 치즈, 튀김기름...
# 1                                     [식빵, 피자치즈, 식용유]
# 2                        [양파, 홍고추, 청고추, 밀가루, 계란, 빵가루]
# 3             [스위트콘, 햄, 표고버섯, 양파, 계란, 슬라이스치즈, 오이, 당근]
# 4                [감자, 오이, 양파, 치즈, 밀가루, 빵가루, 계란, 스위트콘]
# 5                   [돼지고기, 모짜렐라치즈, 청피망, 밀가루, 계란, 빵가루]
# 6                          [계란흰자, 피자치즈, 밀가루, 넛맥, 식용유]
# 7                                 [닭안심, 밀가루, 계란, 빵가루]
# 8               [참치통조림, 양파, 청피망, 두부, 홍피망, 계란노른자, 빵가루]
# 9                [흰밥, 프랑크소시지, 밀가루, 계란, 빵가루, 버터, 카레가루]
# 10               [밀가루, 드라이이스트, 설탕, 소금, 분유, 계란, 물, 버터]
# 11        [새우, 고등어, 굴비, 갈치, 빵가루, 계란, 밀가루, 오렌지, 방울토마토]
# 12                    [토마토, 빵가루, 다진올리브, 다진파슬리, 샐러드오일]
# 13  [돼지고기, 양파, 청피망, 슬라이스치즈, 피자치즈, 피자소스, 밀가루, 계란, 빵...
# 14           [고등어, 오렌지, 샐러리, 허브, 빵가루, 밀가루, 계란, 계란노른자]
# [['새우', '빵가루', '밀가루', '매실', '레몬', '양상추', '꽃상추', '치커리', '알팔파싹']]
# [['새우', '빵가루', '밀가루', '매실', '레몬', '양상추', '꽃상추', '치커리', '알팔파싹'], ['가자미', '양파', '양송이버섯']]
# [['새우', '빵가루', '밀가루', '매실', '레몬', '양상추', '꽃상추', '치커리', '알팔파싹'], ['가자미', '양파', '양송이버섯'], ['단호박', '크림치즈']]
# [['새우', '빵가루', '밀가루', '매실', '레몬', '양상추', '꽃상추', '치커리', '알팔파싹'], ['가자미', '양파', '양송이버섯'], ['단호박', '크림치즈'], ['돼지고기', '부추', '양파', '당근', '배춧잎']]
# [['새우', '빵가루', '밀가루', '매실', '레몬', '양상추', '꽃상추', '치커리', '알팔파싹'], ['가자미', '양파', '양송이버섯'], ['단호박', '크림치즈'], ['돼지고기', '부추', '양파', '당근', '배춧잎'], ['닭안심', '표고버섯', '느타리버섯', '팽이버섯', '당근', '청고추', '계란']]
# [['새우', '빵가루', '밀가루', '매실', '레몬', '양상추', '꽃상추', '치커리', '알팔파싹'], ['가자미', '양파', '양송이버섯'], ['단호박', '크림치즈'], ['돼지고기', '부추', '양파', '당근', '배춧잎'], ['닭안심', '표고버섯', '느타리버섯', '팽이버섯', '당근', '청고추', '계란'], ['갈치', '토마토', '청피망', '홍피망']]
# [['새우', '빵가루', '밀가루', '매실', '레몬', '양상추', '꽃상추', '치커리', '알팔파싹'], ['가자미', '양파', '양송이버섯'], ['단호박', '크림치즈'], ['돼지고기', '부추', '양파', '당근', '배춧잎'], ['닭안심', '표고버섯', '느타리버섯', '팽이버섯', '당근', '청고추', '계란'], ['갈치', '토마토', '청피망', '홍피망'], ['홍합', '버터', '화이트와인', '시금치', '브로콜리']]
# [['새우', '빵가루', '밀가루', '매실', '레몬', '양상추', '꽃상추', '치커리', '알팔파싹'], ['가자미', '양파', '양송이버섯'], ['단호박', '크림치즈'], ['돼지고기', '부추', '양파', '당근', '배춧잎'], ['닭안심', '표고버섯', '느타리버섯', '팽이버섯', '당근', '청고추', '계란'], ['갈치', '토마토', '청피망', '홍피망'], ['홍합', '버터', '화이트와인', '시금치', '브로콜리'], ['생홍합', '바지락', '새우', '가리비', '도미살', '연어살', '블랙올리브', '파인애플', '사과', '딸기', '바나나', '꽃상추']]
# [['새우', '빵가루', '밀가루', '매실', '레몬', '양상추', '꽃상추', '치커리', '알팔파싹'], ['가자미', '양파', '양송이버섯'], ['단호박', '크림치즈'], ['돼지고기', '부추', '양파', '당근', '배춧잎'], ['닭안심', '표고버섯', '느타리버섯', '팽이버섯', '당근', '청고추', '계란'], ['갈치', '토마토', '청피망', '홍피망'], ['홍합', '버터', '화이트와인', '시금치', '브로콜리'], ['생홍합', '바지락', '새우', '가리비', '도미살', '연어살', '블랙올리브', '파인애플', '사과', '딸기', '바나나', '꽃상추'], ['사과', '자몽', '샐러리', '오이', '딸기']]
# [['새우', '빵가루', '밀가루', '매실', '레몬', '양상추', '꽃상추', '치커리', '알팔파싹'], ['가자미', '양파', '양송이버섯'], ['단호박', '크림치즈'], ['돼지고기', '부추', '양파', '당근', '배춧잎'], ['닭안심', '표고버섯', '느타리버섯', '팽이버섯', '당근', '청고추', '계란'], ['갈치', '토마토', '청피망', '홍피망'], ['홍합', '버터', '화이트와인', '시금치', '브로콜리'], ['생홍합', '바지락', '새우', '가리비', '도미살', '연어살', '블랙올리브', '파인애플', '사과', '딸기', '바나나', '꽃상추'], ['사과', '자몽', '샐러리', '오이', '딸기'], ['방울토마토', '키위', '파인애플통조림', '과일통조림', '씨리얼']]
# [['새우', '빵가루', '밀가루', '매실', '레몬', '양상추', '꽃상추', '치커리', '알팔파싹'], ['가자미', '양파', '양송이버섯'], ['단호박', '크림치즈'], ['돼지고기', '부추', '양파', '당근', '배춧잎'], ['닭안심', '표고버섯', '느타리버섯', '팽이버섯', '당근', '청고추', '계란'], ['갈치', '토마토', '청피망', '홍피망'], ['홍합', '버터', '화이트와인', '시금치', '브로콜리'], ['생홍합', '바지락', '새우', '가리비', '도미살', '연어살', '블랙올리브', '파인애플', '사과', '딸기', '바나나', '꽃상추'], ['사과', '자몽', '샐러리', '오이', '딸기'], ['방울토마토', '키위', '파인애플통조림', '과일통조림', '씨리얼'], ['양상추', '피망', '셀러리', '오이']]
# [['새우', '빵가루', '밀가루', '매실', '레몬', '양상추', '꽃상추', '치커리', '알팔파싹'], ['가자미', '양파', '양송이버섯'], ['단호박', '크림치즈'], ['돼지고기', '부추', '양파', '당근', '배춧잎'], ['닭안심', '표고버섯', '느타리버섯', '팽이버섯', '당근', '청고추', '계란'], ['갈치', '토마토', '청피망', '홍피망'], ['홍합', '버터', '화이트와인', '시금치', '브로콜리'], ['생홍합', '바지락', '새우', '가리비', '도미살', '연어살', '블랙올리브', '파인애플', '사과', '딸기', '바나나', '꽃상추'], ['사과', '자몽', '샐러리', '오이', '딸기'], ['방울토마토', '키위', '파인애플통조림', '과일통조림', '씨리얼'], ['양상추', '피망', '셀러리', '오이'], ['닭', '건포도', '잣', '당근', '석류', '체드로', '샐러드']]
# [['새우', '빵가루', '밀가루', '매실', '레몬', '양상추', '꽃상추', '치커리', '알팔파싹'], ['가자미', '양파', '양송이버섯'], ['단호박', '크림치즈'], ['돼지고기', '부추', '양파', '당근', '배춧잎'], ['닭안심', '표고버섯', '느타리버섯', '팽이버섯', '당근', '청고추', '계란'], ['갈치', '토마토', '청피망', '홍피망'], ['홍합', '버터', '화이트와인', '시금치', '브로콜리'], ['생홍합', '바지락', '새우', '가리비', '도미살', '연어살', '블랙올리브', '파인애플', '사과', '딸기', '바나나', '꽃상추'], ['사과', '자몽', '샐러리', '오이', '딸기'], ['방울토마토', '키위', '파인애플통조림', '과일통조림', '씨리얼'], ['양상추', '피망', '셀러리', '오이'], ['닭', '건포도', '잣', '당근', '석류', '체드로', '샐러드'], ['당근', '건포도', '물', '아몬드', '땅콩']]
# [['새우', '빵가루', '밀가루', '매실', '레몬', '양상추', '꽃상추', '치커리', '알팔파싹'], ['가자미', '양파', '양송이버섯'], ['단호박', '크림치즈'], ['돼지고기', '부추', '양파', '당근', '배춧잎'], ['닭안심', '표고버섯', '느타리버섯', '팽이버섯', '당근', '청고추', '계란'], ['갈치', '토마토', '청피망', '홍피망'], ['홍합', '버터', '화이트와인', '시금치', '브로콜리'], ['생홍합', '바지락', '새우', '가리비', '도미살', '연어살', '블랙올리브', '파인애플', '사과', '딸기', '바나나', '꽃상추'], ['사과', '자몽', '샐러리', '오이', '딸기'], ['방울토마토', '키위', '파인애플통조림', '과일통조림', '씨리얼'], ['양상추', '피망', '셀러리', '오이'], ['닭', '건포도', '잣', '당근', '석류', '체드로', '샐러드'], ['당근', '건포도', '물', '아몬드', '땅콩'], ['쇠고기', '건포도', '잣', '아스파라거스', '어린잎채소']]
# [['새우', '빵가루', '밀가루', '매실', '레몬', '양상추', '꽃상추', '치커리', '알팔파싹'], ['가자미', '양파', '양송이버섯'], ['단호박', '크림치즈'], ['돼지고기', '부추', '양파', '당근', '배춧잎'], ['닭안심', '표고버섯', '느타리버섯', '팽이버섯', '당근', '청고추', '계란'], ['갈치', '토마토', '청피망', '홍피망'], ['홍합', '버터', '화이트와인', '시금치', '브로콜리'], ['생홍합', '바지락', '새우', '가리비', '도미살', '연어살', '블랙올리브', '파인애플', '사과', '딸기', '바나나', '꽃상추'], ['사과', '자몽', '샐러리', '오이', '딸기'], ['방울토마토', '키위', '파인애플통조림', '과일통조림', '씨리얼'], ['양상추', '피망', '셀러리', '오이'], ['닭', '건포도', '잣', '당근', '석류', '체드로', '샐러드'], ['당근', '건포도', '물', '아몬드', '땅콩'], ['쇠고기', '건포도', '잣', '아스파라거스', '어린잎채소'], ['브로콜리', '건포도', '피칸', '베이컨', '적양파', '마요네즈', '레드와인비네거', '사워크림', '디종머스터드', '파마산치즈가루', '소금', '후춧가루']]
#                                                    재료
# 0         [새우, 빵가루, 밀가루, 매실, 레몬, 양상추, 꽃상추, 치커리, 알팔파싹]
# ...
# [['닭고기', '스위트콘', '양파', '브로콜리', '우유'], ['가지', '감자', '모짜렐라치즈', '파슬리'], ['쌀', '물', '우유', '파마산치즈', '베이컨'], ['브로콜리', '새우', '밀가루', '치즈'], ['송편', '토마토', '양파', '모짜렐라', '치즈', '파마산', '치즈', '버터'], ['감자', '쇠고기', '계란', '빵가루', '밀가루', '식용유', '레몬즙'], ['식빵', '계란', '양파', '당근', '실파', '파마산치즈', '슬라이스치즈'], ['닭가슴살', '올리브오일', '커리파우더', '소금', '후춧가루', '또띠아', '사과', '샐러드채소']]
# [['닭고기', '스위트콘', '양파', '브로콜리', '우유'], ['가지', '감자', '모짜렐라치즈', '파슬리'], ['쌀', '물', '우유', '파마산치즈', '베이컨'], ['브로콜리', '새우', '밀가루', '치즈'], ['송편', '토마토', '양파', '모짜렐라', '치즈', '파마산', '치즈', '버터'], ['감자', '쇠고기', '계란', '빵가루', '밀가루', '식용유', '레몬즙'], ['식빵', '계란', '양파', '당근', '실파', '파마산치즈', '슬라이스치즈'], ['닭가슴살', '올리브오일', '커리파우더', '소금', '후춧가루', '또띠아', '사과', '샐러드채소'], ['식빵', '햄', '오이피클', '기름', '양파']]
# [['닭고기', '스위트콘', '양파', '브로콜리', '우유'], ['가지', '감자', '모짜렐라치즈', '파슬리'], ['쌀', '물', '우유', '파마산치즈', '베이컨'], ['브로콜리', '새우', '밀가루', '치즈'], ['송편', '토마토', '양파', '모짜렐라', '치즈', '파마산', '치즈', '버터'], ['감자', '쇠고기', '계란', '빵가루', '밀가루', '식용유', '레몬즙'], ['식빵', '계란', '양파', '당근', '실파', '파마산치즈', '슬라이스치즈'], ['닭가슴살', '올리브오일', '커리파우더', '소금', '후춧가루', '또띠아', '사과', '샐러드채소'], ['식빵', '햄', '오이피클', '기름', '양파'], ['모닝빵', '쇠고기', '돼지고기', '양파', '샐러리', '계란노른자', '빵가루', '밀가루', '소금', '베이컨', '피클', '토마토', '양파', '파프리카']]
# [['닭고기', '스위트콘', '양파', '브로콜리', '우유'], ['가지', '감자', '모짜렐라치즈', '파슬리'], ['쌀', '물', '우유', '파마산치즈', '베이컨'], ['브로콜리', '새우', '밀가루', '치즈'], ['송편', '토마토', '양파', '모짜렐라', '치즈', '파마산', '치즈', '버터'], ['감자', '쇠고기', '계란', '빵가루', '밀가루', '식용유', '레몬즙'], ['식빵', '계란', '양파', '당근', '실파', '파마산치즈', '슬라이스치즈'], ['닭가슴살', '올리브오일', '커리파우더', '소금', '후춧가루', '또띠아', '사과', '샐러드채소'], ['식빵', '햄', '오이피클', '기름', '양파'], ['모닝빵', '쇠고기', '돼지고기', '양파', '샐러리', '계란노른자', '빵가루', '밀가루', '소금', '베이컨', '피클', '토마토', '양파', '파프리카'], ['바게트', '토마토', '양파', '상추', '비타민잎', '치즈', '쇠고기']]
# [['닭고기', '스위트콘', '양파', '브로콜리', '우유'], ['가지', '감자', '모짜렐라치즈', '파슬리'], ['쌀', '물', '우유', '파마산치즈', '베이컨'], ['브로콜리', '새우', '밀가루', '치즈'], ['송편', '토마토', '양파', '모짜렐라', '치즈', '파마산', '치즈', '버터'], ['감자', '쇠고기', '계란', '빵가루', '밀가루', '식용유', '레몬즙'], ['식빵', '계란', '양파', '당근', '실파', '파마산치즈', '슬라이스치즈'], ['닭가슴살', '올리브오일', '커리파우더', '소금', '후춧가루', '또띠아', '사과', '샐러드채소'], ['식빵', '햄', '오이피클', '기름', '양파'], ['모닝빵', '쇠고기', '돼지고기', '양파', '샐러리', '계란노른자', '빵가루', '밀가루', '소금', '베이컨', '피클', '토마토', '양파', '파프리카'], ['바게트', '토마토', '양파', '상추', '비타민잎', '치즈', '쇠고기'], ['닭안심', '베이글', '크림치즈', '양상추']]
# [['닭고기', '스위트콘', '양파', '브로콜리', '우유'], ['가지', '감자', '모짜렐라치즈', '파슬리'], ['쌀', '물', '우유', '파마산치즈', '베이컨'], ['브로콜리', '새우', '밀가루', '치즈'], ['송편', '토마토', '양파', '모짜렐라', '치즈', '파마산', '치즈', '버터'], ['감자', '쇠고기', '계란', '빵가루', '밀가루', '식용유', '레몬즙'], ['식빵', '계란', '양파', '당근', '실파', '파마산치즈', '슬라이스치즈'], ['닭가슴살', '올리브오일', '커리파우더', '소금', '후춧가루', '또띠아', '사과', '샐러드채소'], ['식빵', '햄', '오이피클', '기름', '양파'], ['모닝빵', '쇠고기', '돼지고기', '양파', '샐러리', '계란노른자', '빵가루', '밀가루', '소금', '베이컨', '피클', '토마토', '양파', '파프리카'], ['바게트', '토마토', '양파', '상추', '비타민잎', '치즈', '쇠고기'], ['닭안심', '베이글', '크림치즈', '양상추'], ['햄버거빵', '새우', '토마토', '양상추', '슬라이스치즈', '계란', '밀가루', '빵가루']]
# [['닭고기', '스위트콘', '양파', '브로콜리', '우유'], ['가지', '감자', '모짜렐라치즈', '파슬리'], ['쌀', '물', '우유', '파마산치즈', '베이컨'], ['브로콜리', '새우', '밀가루', '치즈'], ['송편', '토마토', '양파', '모짜렐라', '치즈', '파마산', '치즈', '버터'], ['감자', '쇠고기', '계란', '빵가루', '밀가루', '식용유', '레몬즙'], ['식빵', '계란', '양파', '당근', '실파', '파마산치즈', '슬라이스치즈'], ['닭가슴살', '올리브오일', '커리파우더', '소금', '후춧가루', '또띠아', '사과', '샐러드채소'], ['식빵', '햄', '오이피클', '기름', '양파'], ['모닝빵', '쇠고기', '돼지고기', '양파', '샐러리', '계란노른자', '빵가루', '밀가루', '소금', '베이컨', '피클', '토마토', '양파', '파프리카'], ['바게트', '토마토', '양파', '상추', '비타민잎', '치즈', '쇠고기'], ['닭안심', '베이글', '크림치즈', '양상추'], ['햄버거빵', '새우', '토마토', '양상추', '슬라이스치즈', '계란', '밀가루', '빵가루'], ['식빵', '계란', '딸기', '버터', '식용유']]
# [['닭고기', '스위트콘', '양파', '브로콜리', '우유'], ['가지', '감자', '모짜렐라치즈', '파슬리'], ['쌀', '물', '우유', '파마산치즈', '베이컨'], ['브로콜리', '새우', '밀가루', '치즈'], ['송편', '토마토', '양파', '모짜렐라', '치즈', '파마산', '치즈', '버터'], ['감자', '쇠고기', '계란', '빵가루', '밀가루', '식용유', '레몬즙'], ['식빵', '계란', '양파', '당근', '실파', '파마산치즈', '슬라이스치즈'], ['닭가슴살', '올리브오일', '커리파우더', '소금', '후춧가루', '또띠아', '사과', '샐러드채소'], ['식빵', '햄', '오이피클', '기름', '양파'], ['모닝빵', '쇠고기', '돼지고기', '양파', '샐러리', '계란노른자', '빵가루', '밀가루', '소금', '베이컨', '피클', '토마토', '양파', '파프리카'], ['바게트', '토마토', '양파', '상추', '비타민잎', '치즈', '쇠고기'], ['닭안심', '베이글', '크림치즈', '양상추'], ['햄버거빵', '새우', '토마토', '양상추', '슬라이스치즈', '계란', '밀가루', '빵가루'], ['식빵', '계란', '딸기', '버터', '식용유'], ['바게트', '훈제연어', '상추', '체리알', '사워크림']]
#                                                    재료
# 0                           [닭고기, 스위트콘, 양파, 브로콜리, 우유]
# 1                               [가지, 감자, 모짜렐라치즈, 파슬리]
# 2                              [쌀, 물, 우유, 파마산치즈, 베이컨]
# 3                                 [브로콜리, 새우, 밀가루, 치즈]
# 4                [송편, 토마토, 양파, 모짜렐라, 치즈, 파마산, 치즈, 버터]
# 5                   [감자, 쇠고기, 계란, 빵가루, 밀가루, 식용유, 레몬즙]
# 6                 [식빵, 계란, 양파, 당근, 실파, 파마산치즈, 슬라이스치즈]
# 7      [닭가슴살, 올리브오일, 커리파우더, 소금, 후춧가루, 또띠아, 사과, 샐러드채소]
# 8                               [식빵, 햄, 오이피클, 기름, 양파]
# 9   [모닝빵, 쇠고기, 돼지고기, 양파, 샐러리, 계란노른자, 빵가루, 밀가루, 소금,...
# 10                  [바게트, 토마토, 양파, 상추, 비타민잎, 치즈, 쇠고기]
# 11                              [닭안심, 베이글, 크림치즈, 양상추]
# 12         [햄버거빵, 새우, 토마토, 양상추, 슬라이스치즈, 계란, 밀가루, 빵가루]
# 13                              [식빵, 계란, 딸기, 버터, 식용유]
# 14                         [바게트, 훈제연어, 상추, 체리알, 사워크림]
# [['참치', '감자', '양파', '빵가루']]
# [['참치', '감자', '양파', '빵가루'], ['밀가루', '소금', '우유', '토마토', '닭고기', '치즈', '적치커리', '비타민잎', '양파', '식용유']]
# [['참치', '감자', '양파', '빵가루'], ['밀가루', '소금', '우유', '토마토', '닭고기', '치즈', '적치커리', '비타민잎', '양파', '식용유'], ['미니크로아상', '치커리', '슬라이스치즈', '슬라이스햄', '피클']]
# [['참치', '감자', '양파', '빵가루'], ['밀가루', '소금', '우유', '토마토', '닭고기', '치즈', '적치커리', '비타민잎', '양파', '식용유'], ['미니크로아상', '치커리', '슬라이스치즈', '슬라이스햄', '피클'], ['식빵', '양상추', '닭', '베이컨', '토마토']]
# [['참치', '감자', '양파', '빵가루'], ['밀가루', '소금', '우유', '토마토', '닭고기', '치즈', '적치커리', '비타민잎', '양파', '식용유'], ['미니크로아상', '치커리', '슬라이스치즈', '슬라이스햄', '피클'], ['식빵', '양상추', '닭', '베이컨', '토마토'], ['밀가루', '식용유', '물', '토마토', '마늘', '양파', '홍고추', '닭고기', '식용유', '치즈', '베이컨', '양상추']]
# [['참치', '감자', '양파', '빵가루'], ['밀가루', '소금', '우유', '토마토', '닭고기', '치즈', '적치커리', '비타민잎', '양파', '식용유'], ['미니크로아상', '치커리', '슬라이스치즈', '슬라이스햄', '피클'], ['식빵', '양상추', '닭', '베이컨', '토마토'], ['밀가루', '식용유', '물', '토마토', '마늘', '양파', '홍고추', '닭고기', '식용유', '치즈', '베이컨', '양상추'], ['바게트', '감자', '햄', '양파', '옥수수콘']]
# [['참치', '감자', '양파', '빵가루'], ['밀가루', '소금', '우유', '토마토', '닭고기', '치즈', '적치커리', '비타민잎', '양파', '식용유'], ['미니크로아상', '치커리', '슬라이스치즈', '슬라이스햄', '피클'], ['식빵', '양상추', '닭', '베이컨', '토마토'], ['밀가루', '식용유', '물', '토마토', '마늘', '양파', '홍고추', '닭고기', '식용유', '치즈', '베이컨', '양상추'], ['바게트', '감자', '햄', '양파', '옥수수콘'], ['식빵', '버터', '햄', '치즈', '피클', '맛살', '계란']]
# [['참치', '감자', '양파', '빵가루'], ['밀가루', '소금', '우유', '토마토', '닭고기', '치즈', '적치커리', '비타민잎', '양파', '식용유'], ['미니크로아상', '치커리', '슬라이스치즈', '슬라이스햄', '피클'], ['식빵', '양상추', '닭', '베이컨', '토마토'], ['밀가루', '식용유', '물', '토마토', '마늘', '양파', '홍고추', '닭고기', '식용유', '치즈', '베이컨', '양상추'], ['바게트', '감자', '햄', '양파', '옥수수콘'], ['식빵', '버터', '햄', '치즈', '피클', '맛살', '계란'], ['핫도그빵', '프랑크소시지', '양상추', '양파', '오이피클']]
# [['참치', '감자', '양파', '빵가루'], ['밀가루', '소금', '우유', '토마토', '닭고기', '치즈', '적치커리', '비타민잎', '양파', '식용유'], ['미니크로아상', '치커리', '슬라이스치즈', '슬라이스햄', '피클'], ['식빵', '양상추', '닭', '베이컨', '토마토'], ['밀가루', '식용유', '물', '토마토', '마늘', '양파', '홍고추', '닭고기', '식용유', '치즈', '베이컨', '양상추'], ['바게트', '감자', '햄', '양파', '옥수수콘'], ['식빵', '버터', '햄', '치즈', '피클', '맛살', '계란'], ['핫도그빵', '프랑크소시지', '양상추', '양파', '오이피클'], ['크로와상', '흰살생선', '양상추', '가지', '토마토', '양송이버섯', '다진딜', '올리브오일']]
# [['참치', '감자', '양파', '빵가루'], ['밀가루', '소금', '우유', '토마토', '닭고기', '치즈', '적치커리', '비타민잎', '양파', '식용유'], ['미니크로아상', '치커리', '슬라이스치즈', '슬라이스햄', '피클'], ['식빵', '양상추', '닭', '베이컨', '토마토'], ['밀가루', '식용유', '물', '토마토', '마늘', '양파', '홍고추', '닭고기', '식용유', '치즈', '베이컨', '양상추'], ['바게트', '감자', '햄', '양파', '옥수수콘'], ['식빵', '버터', '햄', '치즈', '피클', '맛살', '계란'], ['핫도그빵', '프랑크소시지', '양상추', '양파', '오이피클'], ['크로와상', '흰살생선', '양상추', '가지', '토마토', '양송이버섯', '다진딜', '올리브오일'], ['보리빵', '흰살생선', '양상추', '가지', '토마토', '식용유', '흰후춧가루']]
# [['참치', '감자', '양파', '빵가루'], ['밀가루', '소금', '우유', '토마토', '닭고기', '치즈', '적치커리', '비타민잎', '양파', '식용유'], ['미니크로아상', '치커리', '슬라이스치즈', '슬라이스햄', '피클'], ['식빵', '양상추', '닭', '베이컨', '토마토'], ['밀가루', '식용유', '물', '토마토', '마늘', '양파', '홍고추', '닭고기', '식용유', '치즈', '베이컨', '양상추'], ['바게트', '감자', '햄', '양파', '옥수수콘'], ['식빵', '버터', '햄', '치즈', '피클', '맛살', '계란'], ['핫도그빵', '프랑크소시지', '양상추', '양파', '오이피클'], ['크로와상', '흰살생선', '양상추', '가지', '토마토', '양송이버섯', '다진딜', '올리브오일'], ['보리빵', '흰살생선', '양상추', '가지', '토마토', '식용유', '흰후춧가루'], ['식빵', '햄', '슬라이스치즈']]
# [['참치', '감자', '양파', '빵가루'], ['밀가루', '소금', '우유', '토마토', '닭고기', '치즈', '적치커리', '비타민잎', '양파', '식용유'], ['미니크로아상', '치커리', '슬라이스치즈', '슬라이스햄', '피클'], ['식빵', '양상추', '닭', '베이컨', '토마토'], ['밀가루', '식용유', '물', '토마토', '마늘', '양파', '홍고추', '닭고기', '식용유', '치즈', '베이컨', '양상추'], ['바게트', '감자', '햄', '양파', '옥수수콘'], ['식빵', '버터', '햄', '치즈', '피클', '맛살', '계란'], ['핫도그빵', '프랑크소시지', '양상추', '양파', '오이피클'], ['크로와상', '흰살생선', '양상추', '가지', '토마토', '양송이버섯', '다진딜', '올리브오일'], ['보리빵', '흰살생선', '양상추', '가지', '토마토', '식용유', '흰후춧가루'], ['식빵', '햄', '슬라이스치즈'], ['강력분', '박력분', '올리브오일', '드라이이스트', '물', '바나나', '다진초콜릿', '플레인요구르트', '설탕', '코코아']]
# [['참치', '감자', '양파', '빵가루'], ['밀가루', '소금', '우유', '토마토', '닭고기', '치즈', '적치커리', '비타민잎', '양파', '식용유'], ['미니크로아상', '치커리', '슬라이스치즈', '슬라이스햄', '피클'], ['식빵', '양상추', '닭', '베이컨', '토마토'], ['밀가루', '식용유', '물', '토마토', '마늘', '양파', '홍고추', '닭고기', '식용유', '치즈', '베이컨', '양상추'], ['바게트', '감자', '햄', '양파', '옥수수콘'], ['식빵', '버터', '햄', '치즈', '피클', '맛살', '계란'], ['핫도그빵', '프랑크소시지', '양상추', '양파', '오이피클'], ['크로와상', '흰살생선', '양상추', '가지', '토마토', '양송이버섯', '다진딜', '올리브오일'], ['보리빵', '흰살생선', '양상추', '가지', '토마토', '식용유', '흰후춧가루'], ['식빵', '햄', '슬라이스치즈'], ['강력분', '박력분', '올리브오일', '드라이이스트', '물', '바나나', '다진초콜릿', '플레인요구르트', '설탕', '코코아'], ['밀가루', '이스트', '설탕', '소금', '우유', '물', '버터', '식용유', '식용유', '올리브', '피망', '양파', '모짜렐라치즈']]
# [['참치', '감자', '양파', '빵가루'], ['밀가루', '소금', '우유', '토마토', '닭고기', '치즈', '적치커리', '비타민잎', '양파', '식용유'], ['미니크로아상', '치커리', '슬라이스치즈', '슬라이스햄', '피클'], ['식빵', '양상추', '닭', '베이컨', '토마토'], ['밀가루', '식용유', '물', '토마토', '마늘', '양파', '홍고추', '닭고기', '식용유', '치즈', '베이컨', '양상추'], ['바게트', '감자', '햄', '양파', '옥수수콘'], ['식빵', '버터', '햄', '치즈', '피클', '맛살', '계란'], ['핫도그빵', '프랑크소시지', '양상추', '양파', '오이피클'], ['크로와상', '흰살생선', '양상추', '가지', '토마토', '양송이버섯', '다진딜', '올리브오일'], ['보리빵', '흰살생선', '양상추', '가지', '토마토', '식용유', '흰후춧가루'], ['식빵', '햄', '슬라이스치즈'], ['강력분', '박력분', '올리브오일', '드라이이스트', '물', '바나나', '다진초콜릿', '플레인요구르트', '설탕', '코코아'], ['밀가루', '이스트', '설탕', '소금', '우유', '물', '버터', '식용유', '식용유', '올리브', '피망', '양파', '모짜렐라치즈'], ['밀가루', '식용유', '소시지', '햄', '양송이', '올리브', '피망', '피자치즈', '양파', '샐러리', '토마토']]
# [['참치', '감자', '양파', '빵가루'], ['밀가루', '소금', '우유', '토마토', '닭고기', '치즈', '적치커리', '비타민잎', '양파', '식용유'], ['미니크로아상', '치커리', '슬라이스치즈', '슬라이스햄', '피클'], ['식빵', '양상추', '닭', '베이컨', '토마토'], ['밀가루', '식용유', '물', '토마토', '마늘', '양파', '홍고추', '닭고기', '식용유', '치즈', '베이컨', '양상추'], ['바게트', '감자', '햄', '양파', '옥수수콘'], ['식빵', '버터', '햄', '치즈', '피클', '맛살', '계란'], ['핫도그빵', '프랑크소시지', '양상추', '양파', '오이피클'], ['크로와상', '흰살생선', '양상추', '가지', '토마토', '양송이버섯', '다진딜', '올리브오일'], ['보리빵', '흰살생선', '양상추', '가지', '토마토', '식용유', '흰후춧가루'], ['식빵', '햄', '슬라이스치즈'], ['강력분', '박력분', '올리브오일', '드라이이스트', '물', '바나나', '다진초콜릿', '플레인요구르트', '설탕', '코코아'], ['밀가루', '이스트', '설탕', '소금', '우유', '물', '버터', '식용유', '식용유', '올리브', '피망', '양파', '모짜렐라치즈'], ['밀가루', '식용유', '소시지', '햄', '양송이', '올리브', '피망', '피자치즈', '양파', '샐러리', '토마토'], ['식빵', '피망', '옥수수', '햄', '양송이', '피자치즈', '버터', '식용유']]
#                                                    재료
# 0                                   [참치, 감자, 양파, 빵가루]
# 1    [밀가루, 소금, 우유, 토마토, 닭고기, 치즈, 적치커리, 비타민잎, 양파, 식용유]
# 2                    [미니크로아상, 치커리, 슬라이스치즈, 슬라이스햄, 피클]
# 3                              [식빵, 양상추, 닭, 베이컨, 토마토]
# 4   [밀가루, 식용유, 물, 토마토, 마늘, 양파, 홍고추, 닭고기, 식용유, 치즈, ...
# 5                              [바게트, 감자, 햄, 양파, 옥수수콘]
# 6                         [식빵, 버터, 햄, 치즈, 피클, 맛살, 계란]
# 7                       [핫도그빵, 프랑크소시지, 양상추, 양파, 오이피클]
# 8       [크로와상, 흰살생선, 양상추, 가지, 토마토, 양송이버섯, 다진딜, 올리브오일]
# 9               [보리빵, 흰살생선, 양상추, 가지, 토마토, 식용유, 흰후춧가루]
# 10                                    [식빵, 햄, 슬라이스치즈]
# 11  [강력분, 박력분, 올리브오일, 드라이이스트, 물, 바나나, 다진초콜릿, 플레인요구...
# 12  [밀가루, 이스트, 설탕, 소금, 우유, 물, 버터, 식용유, 식용유, 올리브, 피...
# 13  [밀가루, 식용유, 소시지, 햄, 양송이, 올리브, 피망, 피자치즈, 양파, 샐러리...
# 14               [식빵, 피망, 옥수수, 햄, 양송이, 피자치즈, 버터, 식용유]
# [['계란', '우유', '모짜렐라치즈', '방울토마토']]
# [['계란', '우유', '모짜렐라치즈', '방울토마토'], ['계란', '두부', '청피망', '당근', '우유', '홍피망']]
# [['계란', '우유', '모짜렐라치즈', '방울토마토'], ['계란', '두부', '청피망', '당근', '우유', '홍피망'], ['쇠고기', '건포도', '생표고버섯', '양송이버섯', '느타리버섯', '팽이버섯', '베이컨', '올리브오일', '소금', '파슬리가루']]
# [['계란', '우유', '모짜렐라치즈', '방울토마토'], ['계란', '두부', '청피망', '당근', '우유', '홍피망'], ['쇠고기', '건포도', '생표고버섯', '양송이버섯', '느타리버섯', '팽이버섯', '베이컨', '올리브오일', '소금', '파슬리가루'], ['완두콩', '옥수수', '당근', '감자', '껍질콩', '식용유']]
# [['계란', '우유', '모짜렐라치즈', '방울토마토'], ['계란', '두부', '청피망', '당근', '우유', '홍피망'], ['쇠고기', '건포도', '생표고버섯', '양송이버섯', '느타리버섯', '팽이버섯', '베이컨', '올리브오일', '소금', '파슬리가루'], ['완두콩', '옥수수', '당근', '감자', '껍질콩', '식용유'], ['돼지고기', '밀가루', '식용유', '버터', '양파', '샐러리']]
# [['계란', '우유', '모짜렐라치즈', '방울토마토'], ['계란', '두부', '청피망', '당근', '우유', '홍피망'], ['쇠고기', '건포도', '생표고버섯', '양송이버섯', '느타리버섯', '팽이버섯', '베이컨', '올리브오일', '소금', '파슬리가루'], ['완두콩', '옥수수', '당근', '감자', '껍질콩', '식용유'], ['돼지고기', '밀가루', '식용유', '버터', '양파', '샐러리'], ['베이비콘', '청피망', '홍피망', '양파', '마늘', '버터', '청경채']]
# [['계란', '우유', '모짜렐라치즈', '방울토마토'], ['계란', '두부', '청피망', '당근', '우유', '홍피망'], ['쇠고기', '건포도', '생표고버섯', '양송이버섯', '느타리버섯', '팽이버섯', '베이컨', '올리브오일', '소금', '파슬리가루'], ['완두콩', '옥수수', '당근', '감자', '껍질콩', '식용유'], ['돼지고기', '밀가루', '식용유', '버터', '양파', '샐러리'], ['베이비콘', '청피망', '홍피망', '양파', '마늘', '버터', '청경채'], ['쇠고기', '식용유', '양파', '양송이', '버터', '밀가루', '파프리카', '스톡', '밥', '브로콜리']]
# [['계란', '우유', '모짜렐라치즈', '방울토마토'], ['계란', '두부', '청피망', '당근', '우유', '홍피망'], ['쇠고기', '건포도', '생표고버섯', '양송이버섯', '느타리버섯', '팽이버섯', '베이컨', '올리브오일', '소금', '파슬리가루'], ['완두콩', '옥수수', '당근', '감자', '껍질콩', '식용유'], ['돼지고기', '밀가루', '식용유', '버터', '양파', '샐러리'], ['베이비콘', '청피망', '홍피망', '양파', '마늘', '버터', '청경채'], ['쇠고기', '식용유', '양파', '양송이', '버터', '밀가루', '파프리카', '스톡', '밥', '브로콜리'], ['소시지', '양파', '양송이버섯', '피망', '당근', '식용유']]
# [['계란', '우유', '모짜렐라치즈', '방울토마토'], ['계란', '두부', '청피망', '당근', '우유', '홍피망'], ['쇠고기', '건포도', '생표고버섯', '양송이버섯', '느타리버섯', '팽이버섯', '베이컨', '올리브오일', '소금', '파슬리가루'], ['완두콩', '옥수수', '당근', '감자', '껍질콩', '식용유'], ['돼지고기', '밀가루', '식용유', '버터', '양파', '샐러리'], ['베이비콘', '청피망', '홍피망', '양파', '마늘', '버터', '청경채'], ['쇠고기', '식용유', '양파', '양송이', '버터', '밀가루', '파프리카', '스톡', '밥', '브로콜리'], ['소시지', '양파', '양송이버섯', '피망', '당근', '식용유'], ['아스파라거스', '새우', '샐러리']]
# [['계란', '우유', '모짜렐라치즈', '방울토마토'], ['계란', '두부', '청피망', '당근', '우유', '홍피망'], ['쇠고기', '건포도', '생표고버섯', '양송이버섯', '느타리버섯', '팽이버섯', '베이컨', '올리브오일', '소금', '파슬리가루'], ['완두콩', '옥수수', '당근', '감자', '껍질콩', '식용유'], ['돼지고기', '밀가루', '식용유', '버터', '양파', '샐러리'], ['베이비콘', '청피망', '홍피망', '양파', '마늘', '버터', '청경채'], ['쇠고기', '식용유', '양파', '양송이', '버터', '밀가루', '파프리카', '스톡', '밥', '브로콜리'], ['소시지', '양파', '양송이버섯', '피망', '당근', '식용유'], ['아스파라거스', '새우', '샐러리'], ['다진쇠고기', '다진돼지고기', '소금', '다진마늘', '계란', '밀가루', '식용유', '후춧가루']]
# [['계란', '우유', '모짜렐라치즈', '방울토마토'], ['계란', '두부', '청피망', '당근', '우유', '홍피망'], ['쇠고기', '건포도', '생표고버섯', '양송이버섯', '느타리버섯', '팽이버섯', '베이컨', '올리브오일', '소금', '파슬리가루'], ['완두콩', '옥수수', '당근', '감자', '껍질콩', '식용유'], ['돼지고기', '밀가루', '식용유', '버터', '양파', '샐러리'], ['베이비콘', '청피망', '홍피망', '양파', '마늘', '버터', '청경채'], ['쇠고기', '식용유', '양파', '양송이', '버터', '밀가루', '파프리카', '스톡', '밥', '브로콜리'], ['소시지', '양파', '양송이버섯', '피망', '당근', '식용유'], ['아스파라거스', '새우', '샐러리'], ['다진쇠고기', '다진돼지고기', '소금', '다진마늘', '계란', '밀가루', '식용유', '후춧가루'], ['육수', '피망', '양송이', '양파', '통마늘', '쇠고기', '밀가루', '쇠고기']]
#                                                    재료
# 0                             [계란, 우유, 모짜렐라치즈, 방울토마토]
# 1                          [계란, 두부, 청피망, 당근, 우유, 홍피망]
# 2   [쇠고기, 건포도, 생표고버섯, 양송이버섯, 느타리버섯, 팽이버섯, 베이컨, 올리브...
# 3                        [완두콩, 옥수수, 당근, 감자, 껍질콩, 식용유]
# 4                       [돼지고기, 밀가루, 식용유, 버터, 양파, 샐러리]
# 5                   [베이비콘, 청피망, 홍피망, 양파, 마늘, 버터, 청경채]
# 6     [쇠고기, 식용유, 양파, 양송이, 버터, 밀가루, 파프리카, 스톡, 밥, 브로콜리]
# 7                       [소시지, 양파, 양송이버섯, 피망, 당근, 식용유]
# 8                                   [아스파라거스, 새우, 샐러리]
# 9       [다진쇠고기, 다진돼지고기, 소금, 다진마늘, 계란, 밀가루, 식용유, 후춧가루]
# 10              [육수, 피망, 양송이, 양파, 통마늘, 쇠고기, 밀가루, 쇠고기]

# %%
result
# Out:
#              음식                                               재료
# 0          감자수프                 [감자, 양파, 대파, 버터, 육수, 계란노른자, 생크림]
# 1         고구마스프                                        [고구마, 우유]
# 2       단호박크림수프                   [단호박, 양파, 버터, 밀가루, 물, 우유, 생크림]
# 3        닭살크림수프                    [닭, 당근, 양파, 밀가루, 버터, 우유, 닭육수]
# 4      덴마크식당근스프                    [버터, 양파, 당근, 크림치즈, 우유, 다진파슬리]
# ..          ...                                              ...
# 426    비프스트로가노프  [쇠고기, 식용유, 양파, 양송이, 버터, 밀가루, 파프리카, 스톡, 밥, 브로콜리]
# 427   소시지채소케첩볶음                    [소시지, 양파, 양송이버섯, 피망, 당근, 식용유]
# 428  아스파라거스새우볶음                                [아스파라거스, 새우, 샐러리]
# 429     와인소스미트볼    [다진쇠고기, 다진돼지고기, 소금, 다진마늘, 계란, 밀가루, 식용유, 후춧가루]
# 430     퓨전찹스테이크            [육수, 피망, 양송이, 양파, 통마늘, 쇠고기, 밀가루, 쇠고기]
#
# [431 rows x 2 columns]

# %%
result.to_csv("양식_recipe.csv")

# %%
#fd_nm에는 음식이름으로 862x1 로 되어있음

# %% [markdown]
# ### 음식 이름 젤 비슷한 메뉴의 재료 목록 가져오는 시스템
# ### ex) 양송이스프 -> 양송이크림스프 의 재료 가져옴

# %%
def find_key_zacard(A,B):
    #A는 입력 데이터
    #B는 컬럼
    tmp_similar=0
    key=""
    for i in B:
        #print(i)
        
        intersection_cardinality = len(set.intersection(*[set(A), set(i)]))
        union_cardinality = len(set.union(*[set(A), set(i)]))
        similar = intersection_cardinality / float(union_cardinality)
       
        
        if similar >= tmp_similar:
            key = i
            tmp_similar = similar
        #print(similar)
        #print(key)
          
    return key

# %%
def find_ingred(input_dt,result):
    found_key = find_key_zacard(input_dt,result['음식'])
    
    tmp_ingred_ = result[result['음식']==found_key]
    tmp_ingred_ = tmp_ingred_.set_index(np.array(range(len(tmp_ingred_))))
    final = []
    
    for i in range(len(tmp_ingred_)):
        final = final + tmp_ingred_['재료'][i]
        
    final = set(final)
    #print(found_key)
    
    return [found_key,final]

# %%
input_dt = "시저 치즈 샐러드"

find_ingred(input_dt, result)
# Out:
# ['시저샐러드', {'방울토마토', '식빵', '양상추', '양파', '치커리', '향신료'}]

# %%
result
# Out:
#              음식                                               재료
# 0          감자수프                 [감자, 양파, 대파, 버터, 육수, 계란노른자, 생크림]
# 1         고구마스프                                        [고구마, 우유]
# 2       단호박크림수프                   [단호박, 양파, 버터, 밀가루, 물, 우유, 생크림]
# 3        닭살크림수프                    [닭, 당근, 양파, 밀가루, 버터, 우유, 닭육수]
# 4      덴마크식당근스프                    [버터, 양파, 당근, 크림치즈, 우유, 다진파슬리]
# ..          ...                                              ...
# 426    비프스트로가노프  [쇠고기, 식용유, 양파, 양송이, 버터, 밀가루, 파프리카, 스톡, 밥, 브로콜리]
# 427   소시지채소케첩볶음                    [소시지, 양파, 양송이버섯, 피망, 당근, 식용유]
# 428  아스파라거스새우볶음                                [아스파라거스, 새우, 샐러리]
# 429     와인소스미트볼    [다진쇠고기, 다진돼지고기, 소금, 다진마늘, 계란, 밀가루, 식용유, 후춧가루]
# 430     퓨전찹스테이크            [육수, 피망, 양송이, 양파, 통마늘, 쇠고기, 밀가루, 쇠고기]
#
# [431 rows x 2 columns]
